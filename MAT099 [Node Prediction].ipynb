# %%
import pandas as pd
import numpy as np
import torch
import dgl

def prepare_graph_data(graphs_file_path, edges_file_path, nodes_file_path, 
                       train_ratio, val_ratio, test_ratio, bidirectional):
    # Reading node and edge data
    node_df = pd.read_csv(nodes_file_path)
    graph_df = pd.read_csv(graphs_file_path)
    edges_df = pd.read_csv(edges_file_path)

    # Initializing feature lists, graph list, and mask lists
    dgl_graphs = []

    # Processing each graph
    for graph_id in graph_df['graph_id']:
        num_nodes = graph_df.loc[graph_df['graph_id'] == graph_id]['num_nodes'].values[0]

        # Initializing node and edge feature arrays and labels
        node_feat = np.zeros((num_nodes, 4))
        edge_feat_proportion = np.zeros((num_nodes, 3), dtype=float)
        room_type_label = np.zeros(num_nodes)

        src_dst_connectivity = edges_df[(edges_df['graph_id'] == graph_id)][['src', 'dst', 'connectivity']]
        connectivity_counts = {0: 0, 1: 0, 2: 0}
        edge_feat = np.zeros((num_nodes, 3))

        # Calculating connectivity counts and edge features
        for _, row in src_dst_connectivity.iterrows():
            src, dst, connectivity = row['src'], row['dst'], row['connectivity']
            edge_feat[src, connectivity] += 1
            connectivity_counts[connectivity] += 1

        # Calculating proportions for edge features
        for src in range(num_nodes):
            for connectivity in range(3):
                total = connectivity_counts[connectivity]
                if total > 0:
                    edge_feat_proportion[src, connectivity] = edge_feat[src, connectivity] / total

        # Assigning node features and labels
        for node_id in range(num_nodes):
            zoning_type = node_df.loc[(node_df['graph_id'] == graph_id) & (node_df['node_id'] == node_id)]['zoning_type'].values[0]
            node_feat[node_id, zoning_type] = 1
            room_type_label[node_id] = node_df.loc[(node_df['graph_id'] == graph_id) & (node_df['node_id'] == node_id)]['room_type'].values[0]

        # Randomly splitting nodes into train, val, and test sets
        num_train = int(train_ratio * num_nodes)
        num_val = int(val_ratio * num_nodes)
        num_test = num_nodes - num_train - num_val

        perm = np.random.permutation(num_nodes)
        train_mask = np.zeros(num_nodes, dtype=bool)
        train_mask[perm[:num_train]] = True
        val_mask = np.zeros(num_nodes, dtype=bool)
        val_mask[perm[num_train:num_train + num_val]] = True
        test_mask = np.zeros(num_nodes, dtype=bool)
        test_mask[perm[num_train + num_val:]] = True

        # Creating the DGL graph
        src_list = src_dst_connectivity["src"].tolist()
        dst_list = src_dst_connectivity["dst"].tolist()
        dgl_graph = dgl.graph((src_list, dst_list), num_nodes=num_nodes)

        feat = torch.cat((torch.tensor(node_feat), torch.tensor(edge_feat_proportion)), dim=1).float()
        label = torch.tensor(room_type_label).to(torch.int64)

        dgl_graph.ndata["feat"] = feat
        dgl_graph.ndata["label"] = label
        dgl_graph.ndata["train_mask"] = torch.tensor(train_mask)
        dgl_graph.ndata["test_mask"] = torch.tensor(test_mask)
        dgl_graph.ndata["val_mask"] = torch.tensor(val_mask)

        if bidirectional:
            dgl_graph = dgl.add_reverse_edges(dgl_graph)        

        dgl_graphs.append(dgl_graph)

    return dgl_graphs

# %%
# Usage Example
graphs_file_path = "C:/Users/c22109646/Downloads/graphs_data.csv"
edges_file_path = "C:/Users/c22109646/Downloads/edges_data_1.csv"
nodes_file_path = "C:/Users/c22109646/Downloads/nodes_data_1.csv"


dgl_graphs = prepare_graph_data(graphs_file_path, edges_file_path, nodes_file_path,
                                train_ratio=0.8, val_ratio=0.1, test_ratio=0.1,
                                bidirectional=True)

# %%
dgl_graphs[:5]
# Out:
# [Graph(num_nodes=18, num_edges=76,
#        ndata_schemes={'feat': Scheme(shape=(7,), dtype=torch.float32), 'label': Scheme(shape=(), dtype=torch.int64), 'train_mask': Scheme(shape=(), dtype=torch.bool), 'test_mask': Scheme(shape=(), dtype=torch.bool), 'val_mask': Scheme(shape=(), dtype=torch.bool)}
#        edata_schemes={}),
#  Graph(num_nodes=25, num_edges=92,
#        ndata_schemes={'feat': Scheme(shape=(7,), dtype=torch.float32), 'label': Scheme(shape=(), dtype=torch.int64), 'train_mask': Scheme(shape=(), dtype=torch.bool), 'test_mask': Scheme(shape=(), dtype=torch.bool), 'val_mask': Scheme(shape=(), dtype=torch.bool)}
#        edata_schemes={}),
#  Graph(num_nodes=60, num_edges=236,
#        ndata_schemes={'feat': Scheme(shape=(7,), dtype=torch.float32), 'label': Scheme(shape=(), dtype=torch.int64), 'train_mask': Scheme(shape=(), dtype=torch.bool), 'test_mask': Scheme(shape=(), dtype=torch.bool), 'val_mask': Scheme(shape=(), dtype=torch.bool)}
#        edata_schemes={}),
#  Graph(num_nodes=19, num_edges=64,
#        ndata_schemes={'feat': Scheme(shape=(7,), dtype=torch.float32), 'label': Scheme(shape=(), dtype=torch.int64), 'train_mask': Scheme(shape=(), dtype=torch.bool), 'test_mask': Scheme(shape=(), dtype=torch.bool), 'val_mask': Scheme(shape=(), dtype=torch.bool)}
#        edata_schemes={}),
#  Graph(num_nodes=16, num_edges=60,
#        ndata_schemes={'feat': Scheme(shape=(7,), dtype=torch.float32), 'label': Scheme(shape=(), dtype=torch.int64), 'train_mask': Scheme(shape=(), dtype=torch.bool), 'test_mask': Scheme(shape=(), dtype=torch.bool), 'val_mask': Scheme(shape=(), dtype=torch.bool)}
#        edata_schemes={})]

# %%
len(dgl_graphs)
# Out:
# 4167

# %%
dgl_graphs[1].ndata
# Out:
# {'feat': tensor([[0.0000, 1.0000, 0.0000, 0.0000, 0.3333, 0.1471, 0.1667],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0882, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.1667, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.1667, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0588, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.1471, 0.1667],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.1667, 0.0882, 0.1667],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.1667, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0588, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0588, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0294, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000]]), 'label': tensor([4, 7, 1, 2, 8, 6, 0, 6, 0, 6, 1, 7, 6, 0, 8, 2, 4, 4, 6, 1, 2, 7, 5, 5,
#         5]), 'train_mask': tensor([ True,  True,  True, False,  True,  True, False,  True,  True,  True,
#          True,  True,  True,  True,  True, False,  True,  True,  True,  True,
#         False,  True,  True, False,  True]), 'test_mask': tensor([False, False, False,  True, False, False,  True, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False,  True, False]), 'val_mask': tensor([False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False])}

# %%
import dgl.nn as dglnn
import torch.nn as nn
import torch.nn.functional as F

class SAGEModel(nn.Module):
    def __init__(self, in_feats, num_classes, params):
        """
        Initialize the GraphSAGE model.
        
        Parameters:
        in_feats (int): The number of input features.
        num_classes (int): The number of classes for classification.
        params (dict): The hyperparameters for the model, including
                       - 'hidden_units': The number of hidden units.
                       - 'num_hidden_layers': The number of hidden layers.
                       - 'activation': The activation function to be used.
        """
        super(SAGEModel, self).__init__()
        
        self.layers = nn.ModuleList()  # To store the GraphSAGE layers.
        self.batch_norms = nn.ModuleList()  # To store the BatchNorm layers.
        self.activation = params['activation']  # The activation function to be used.
        
        # Input layer: appending the first GraphSAGE layer and its corresponding BatchNorm layer.
        self.layers.append(dglnn.SAGEConv(in_feats, params['hidden_units'], 'pool'))
        self.batch_norms.append(nn.BatchNorm1d(params['hidden_units']))
        
        # Hidden layers: appending the hidden GraphSAGE layers and their corresponding BatchNorm layers.
        for _ in range(params['num_hidden_layers']):
            self.layers.append(dglnn.SAGEConv(params['hidden_units'], params['hidden_units'], 'pool'))
            self.batch_norms.append(nn.BatchNorm1d(params['hidden_units']))
        
        # Output layer: appending the final GraphSAGE layer for classification.
        self.layers.append(dglnn.SAGEConv(params['hidden_units'], num_classes, 'pool'))

    def forward(self, g, in_feat):
        """
        Forward computation on the graph.
        
        Parameters:
        g (DGLGraph): The input DGL graph object.
        in_feat (torch.Tensor): The input feature tensor.
        
        Returns:
        h (torch.Tensor): The output feature tensor.
        """
        h = in_feat  # Initial feature assignment
        # Iterate over all layers except the last one, applying the GraphSAGE layer,
        # followed by batch normalization and activation function.
        for i in range(len(self.layers) - 1):
            h = self.layers[i](g, h)  # GraphSAGE layer
            h = self.batch_norms[i](h)  # Batch normalization
            h = getattr(F, self.activation)(h)  # Activation function
        
        h = self.layers[-1](g, h)  # For the last layer, only the GraphSAGE layer is applied without any activation.
        return h

# %%
import torch
import torch.nn.functional as F
import time
from dgl.dataloading import GraphDataLoader

def _TrainClassifier_NC(graphs, model, hparams, batch_size):
    """
    Train a classifier on the provided graph dataset.
    
    Parameters:
    graphs: The input graph dataset.
    model: The model to be trained.
    hparams: Hyperparameters for training.
    batch_size: The batch size for training.
    
    Returns:
    model: The trained model.
    val_acc: The best validation accuracy achieved by the model.
    total_time: The total time spent training the model.
    """
    
    # Creating a DataLoader to batch graphs
    dataloader = GraphDataLoader(graphs, batch_size=batch_size, shuffle=True, drop_last=False)
    
    # Default optimizer
    optimizer = None
    if hparams.optimizer_str.lower() == "adadelta":
        optimizer = torch.optim.Adadelta(model.parameters(), eps=hparams.eps, 
                                            lr=hparams.lr, rho=hparams.rho, weight_decay=hparams.weight_decay)
    elif hparams.optimizer_str.lower() == "adagrad":
        optimizer = torch.optim.Adagrad(model.parameters(), eps=hparams.eps, 
                                            lr=hparams.lr, lr_decay=hparams.lr_decay, weight_decay=hparams.weight_decay)
    elif hparams.optimizer_str.lower() == "adam":
        optimizer = torch.optim.Adam(model.parameters(), amsgrad=hparams.amsgrad, betas=hparams.betas, eps=hparams.eps, 
                                            lr=hparams.lr, maximize=hparams.maximize, weight_decay=hparams.weight_decay)
    
    best_val_acc = 0 
    best_model_state = None  # Store the state_dict of the model with the best validation accuracy
    total_time = 0 
    
    for e in range(hparams.epochs):
        start_time = time.time()  #
        model.train() 
        total_loss = torch.tensor(0.0) 

        for g in dataloader: 
            if not g.ndata: 
                continue
            
            # Extracting features, labels, and train_mask from the current batch
            features, labels, train_mask = g.ndata['feat'], g.ndata['label'], g.ndata['train_mask']
            logits = model(g, features)  # Forward pass
            
            # Compute loss only on the nodes specified by train_mask
            loss = F.cross_entropy(logits[train_mask], labels[train_mask]) if hparams.loss_function.lower() == "cross entropy" else None
            
            # Perform backpropagation and optimizer step
            optimizer.zero_grad() 
            loss.backward() 
            optimizer.step()  
            
            total_loss += loss 
        
        # Calculate average loss for the epoch
        average_loss = total_loss / len(dataloader)
        
        
        val_dataloader = GraphDataLoader(graphs, batch_size=32, shuffle=False, drop_last=False)
        model.eval()  
        total_val_acc = 0.0  
        
        # Evaluate model on the validation set
        for val_batched_graph in val_dataloader:
            # Extracting features, labels, and val_mask from the current validation batch
            val_features, val_labels, val_mask = val_batched_graph.ndata['feat'], val_batched_graph.ndata['label'], val_batched_graph.ndata['val_mask']
            val_logits = model(val_batched_graph, val_features) 
            val_pred = val_logits.argmax(1)  
            total_val_acc += (val_pred[val_mask] == val_labels[val_mask]).float().mean().item() 
        
        end_time = time.time() 
        elapsed_time = end_time - start_time 
        val_acc = total_val_acc / len(val_dataloader) 
        
       
        print(f'Epoch {e}, Loss: {average_loss:.4f}, Val Acc: {val_acc:.4f}, Training time: {elapsed_time:.4f} seconds')
        total_time += elapsed_time  # Accumulate the total training time
        
        # If current val_acc is better than the best so far, update best_val_acc and save the model state
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_state = model.state_dict().copy()
        
    # Load the best model state
    model.load_state_dict(best_model_state)
    return model, best_val_acc, total_time

# %%
import random
from dgl.nn import GINConv, GraphConv, SAGEConv, TAGConv
from topologicpy.DGL import DGL
# Define the Hyper-parameters

optimizer = DGL.Optimizer()
hparams_class = DGL.Hyperparameters(optimizer=optimizer,
                                    model_type="Classifier",
                                    cv_type="Holdout",               
                                    epochs=20,
                                    loss_function="Cross Entropy",
                                    )

# %%
from sklearn.model_selection import ParameterGrid
from dgl.dataloading import GraphDataLoader


param_grid = {
    'num_hidden_layers': [2,3,4,5],  
    'hidden_units': [16,32,64],  
    'activation': ['relu','tanh'],
    'learning_rate': [0.01, 0.005,0.001],
    'batch_size': [16,32,64]
}

best_acc = 0.0  # Initialize the best accuracy
best_params = None  # Initialize the best parameters

# Iterate over combinations of hyperparameters
for params in ParameterGrid(param_grid):
    print(params)
    optimizer = DGL.Optimizer(lr=params['learning_rate'])
    
    # Create a model instance and set hyperparameters
    model = SAGEModel(in_feats=7, num_classes=9, params=params)  # Ensure that SAGEModel is properly defined and imported
    
    # Train the model
    model, val_acc, total_time = _TrainClassifier_NC(dgl_graphs, 
                                                     model, 
                                                     hparams_class,
                                                     batch_size=params['batch_size'])
    
    # Update the best accuracy and best parameters if the current model performs better on the validation set
    if val_acc > best_acc:
        best_acc = val_acc
        best_params = params
        best_model = model 
    print(f'Total Time: {total_time} seconds')  

# Print the best accuracy and best parameters
print('Best Validation Accuracy: ', best_acc)
print('Best Parameters: ', best_params)

if best_model is not None:
    torch.save(best_model.state_dict(), 'best_model.pth')
# Out:
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.01, 'num_hidden_layers': 2}
# Epoch 0, Loss: 1.2207, Val Acc: 0.8554, Training time: 3.1040 seconds
# Epoch 1, Loss: 0.4232, Val Acc: 0.8870, Training time: 3.1620 seconds
# Epoch 2, Loss: 0.3346, Val Acc: 0.8928, Training time: 3.2720 seconds
# Epoch 3, Loss: 0.3023, Val Acc: 0.9008, Training time: 3.4030 seconds
# Epoch 4, Loss: 0.2767, Val Acc: 0.9066, Training time: 3.4450 seconds
# Epoch 5, Loss: 0.2567, Val Acc: 0.9122, Training time: 3.5170 seconds
# Epoch 6, Loss: 0.2447, Val Acc: 0.9140, Training time: 3.4700 seconds
# Epoch 7, Loss: 0.2361, Val Acc: 0.9150, Training time: 3.4900 seconds
# Epoch 8, Loss: 0.2301, Val Acc: 0.9187, Training time: 3.5940 seconds
# Epoch 9, Loss: 0.2262, Val Acc: 0.9160, Training time: 3.5320 seconds
# Epoch 10, Loss: 0.2226, Val Acc: 0.9226, Training time: 3.5990 seconds
# Epoch 11, Loss: 0.2188, Val Acc: 0.9227, Training time: 3.7000 seconds
# Epoch 12, Loss: 0.2166, Val Acc: 0.9241, Training time: 3.5820 seconds
# Epoch 13, Loss: 0.2136, Val Acc: 0.9230, Training time: 3.5540 seconds
# Epoch 14, Loss: 0.2119, Val Acc: 0.9243, Training time: 3.5340 seconds
# Epoch 15, Loss: 0.2100, Val Acc: 0.9249, Training time: 3.5300 seconds
# Epoch 16, Loss: 0.2090, Val Acc: 0.9248, Training time: 3.5240 seconds
# Epoch 17, Loss: 0.2073, Val Acc: 0.9231, Training time: 3.6180 seconds
# Epoch 18, Loss: 0.2058, Val Acc: 0.9263, Training time: 3.5320 seconds
# Epoch 19, Loss: 0.2041, Val Acc: 0.9272, Training time: 3.5770 seconds
# Total Time: 69.73902010917664 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.01, 'num_hidden_layers': 3}
# Epoch 0, Loss: 1.0565, Val Acc: 0.8581, Training time: 4.9600 seconds
# Epoch 1, Loss: 0.4295, Val Acc: 0.8893, Training time: 4.3150 seconds
# Epoch 2, Loss: 0.3219, Val Acc: 0.9047, Training time: 4.2290 seconds
# Epoch 3, Loss: 0.2791, Val Acc: 0.9118, Training time: 4.4270 seconds
# Epoch 4, Loss: 0.2574, Val Acc: 0.9159, Training time: 4.6640 seconds
# Epoch 5, Loss: 0.2444, Val Acc: 0.9179, Training time: 4.6170 seconds
# Epoch 6, Loss: 0.2359, Val Acc: 0.9196, Training time: 4.5890 seconds
# Epoch 7, Loss: 0.2303, Val Acc: 0.9213, Training time: 4.5770 seconds
# Epoch 8, Loss: 0.2249, Val Acc: 0.9224, Training time: 4.7830 seconds
# Epoch 9, Loss: 0.2209, Val Acc: 0.9232, Training time: 4.5870 seconds
# Epoch 10, Loss: 0.2178, Val Acc: 0.9241, Training time: 4.6640 seconds
# Epoch 11, Loss: 0.2145, Val Acc: 0.9249, Training time: 4.6150 seconds
# Epoch 12, Loss: 0.2131, Val Acc: 0.9271, Training time: 4.6360 seconds
# Epoch 13, Loss: 0.2098, Val Acc: 0.9262, Training time: 4.6000 seconds
# Epoch 14, Loss: 0.2071, Val Acc: 0.9260, Training time: 4.6240 seconds
# Epoch 15, Loss: 0.2064, Val Acc: 0.9264, Training time: 4.6430 seconds
# Epoch 16, Loss: 0.2039, Val Acc: 0.9287, Training time: 4.6440 seconds
# Epoch 17, Loss: 0.2012, Val Acc: 0.9287, Training time: 4.6980 seconds
# Epoch 18, Loss: 0.2002, Val Acc: 0.9285, Training time: 4.6230 seconds
# Epoch 19, Loss: 0.1996, Val Acc: 0.9282, Training time: 4.7260 seconds
# Total Time: 92.22102546691895 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.01, 'num_hidden_layers': 4}
# Epoch 0, Loss: 1.1676, Val Acc: 0.8213, Training time: 5.7010 seconds
# Epoch 1, Loss: 0.4897, Val Acc: 0.8775, Training time: 5.8330 seconds
# Epoch 2, Loss: 0.3428, Val Acc: 0.8958, Training time: 5.6130 seconds
# Epoch 3, Loss: 0.2894, Val Acc: 0.9048, Training time: 5.7700 seconds
# Epoch 4, Loss: 0.2660, Val Acc: 0.9119, Training time: 5.5440 seconds
# Epoch 5, Loss: 0.2526, Val Acc: 0.9136, Training time: 5.5610 seconds
# Epoch 6, Loss: 0.2439, Val Acc: 0.9158, Training time: 5.5880 seconds
# Epoch 7, Loss: 0.2375, Val Acc: 0.9206, Training time: 5.6550 seconds
# Epoch 8, Loss: 0.2319, Val Acc: 0.9203, Training time: 5.9760 seconds
# Epoch 9, Loss: 0.2270, Val Acc: 0.9193, Training time: 5.6210 seconds
# Epoch 10, Loss: 0.2248, Val Acc: 0.9229, Training time: 5.5990 seconds
# Epoch 11, Loss: 0.2202, Val Acc: 0.9235, Training time: 5.6640 seconds
# Epoch 12, Loss: 0.2171, Val Acc: 0.9255, Training time: 5.6430 seconds
# Epoch 13, Loss: 0.2147, Val Acc: 0.9247, Training time: 5.6250 seconds
# Epoch 14, Loss: 0.2117, Val Acc: 0.9252, Training time: 5.6580 seconds
# Epoch 15, Loss: 0.2093, Val Acc: 0.9265, Training time: 5.6220 seconds
# Epoch 16, Loss: 0.2090, Val Acc: 0.9271, Training time: 5.8910 seconds
# Epoch 17, Loss: 0.2052, Val Acc: 0.9269, Training time: 5.7030 seconds
# Epoch 18, Loss: 0.2035, Val Acc: 0.9286, Training time: 5.6720 seconds
# Epoch 19, Loss: 0.2018, Val Acc: 0.9259, Training time: 5.8130 seconds
# Total Time: 113.75203347206116 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.01, 'num_hidden_layers': 5}
# Epoch 0, Loss: 1.2514, Val Acc: 0.8204, Training time: 6.5980 seconds
# Epoch 1, Loss: 0.4995, Val Acc: 0.8783, Training time: 6.6130 seconds
# Epoch 2, Loss: 0.3572, Val Acc: 0.8927, Training time: 6.6010 seconds
# Epoch 3, Loss: 0.3102, Val Acc: 0.9011, Training time: 6.7120 seconds
# Epoch 4, Loss: 0.2780, Val Acc: 0.9104, Training time: 6.5600 seconds
# Epoch 5, Loss: 0.2592, Val Acc: 0.9134, Training time: 6.6440 seconds
# Epoch 6, Loss: 0.2464, Val Acc: 0.9154, Training time: 6.7750 seconds
# Epoch 7, Loss: 0.2376, Val Acc: 0.9192, Training time: 6.6680 seconds
# Epoch 8, Loss: 0.2322, Val Acc: 0.9189, Training time: 6.8130 seconds
# Epoch 9, Loss: 0.2265, Val Acc: 0.9217, Training time: 6.7860 seconds
# Epoch 10, Loss: 0.2209, Val Acc: 0.9216, Training time: 6.6740 seconds
# Epoch 11, Loss: 0.2173, Val Acc: 0.9228, Training time: 6.7870 seconds
# Epoch 12, Loss: 0.2149, Val Acc: 0.9235, Training time: 6.8720 seconds
# Epoch 13, Loss: 0.2115, Val Acc: 0.9243, Training time: 6.7070 seconds
# Epoch 14, Loss: 0.2102, Val Acc: 0.9239, Training time: 6.7050 seconds
# Epoch 15, Loss: 0.2080, Val Acc: 0.9250, Training time: 6.8020 seconds
# Epoch 16, Loss: 0.2063, Val Acc: 0.9255, Training time: 6.7840 seconds
# Epoch 17, Loss: 0.2026, Val Acc: 0.9262, Training time: 6.9250 seconds
# Epoch 18, Loss: 0.2030, Val Acc: 0.9258, Training time: 7.0150 seconds
# Epoch 19, Loss: 0.2021, Val Acc: 0.9274, Training time: 7.2030 seconds
# Total Time: 135.2440402507782 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.005, 'num_hidden_layers': 2}
# Epoch 0, Loss: 1.3587, Val Acc: 0.8497, Training time: 4.2640 seconds
# Epoch 1, Loss: 0.4410, Val Acc: 0.8969, Training time: 4.2260 seconds
# Epoch 2, Loss: 0.3187, Val Acc: 0.9068, Training time: 4.2690 seconds
# Epoch 3, Loss: 0.2793, Val Acc: 0.9110, Training time: 4.2550 seconds
# Epoch 4, Loss: 0.2587, Val Acc: 0.9148, Training time: 4.2110 seconds
# Epoch 5, Loss: 0.2455, Val Acc: 0.9176, Training time: 4.3410 seconds
# Epoch 6, Loss: 0.2374, Val Acc: 0.9188, Training time: 4.2900 seconds
# Epoch 7, Loss: 0.2309, Val Acc: 0.9213, Training time: 4.3320 seconds
# Epoch 8, Loss: 0.2281, Val Acc: 0.9226, Training time: 4.3210 seconds
# Epoch 9, Loss: 0.2229, Val Acc: 0.9231, Training time: 4.3910 seconds
# Epoch 10, Loss: 0.2198, Val Acc: 0.9251, Training time: 4.4840 seconds
# Epoch 11, Loss: 0.2174, Val Acc: 0.9252, Training time: 4.3610 seconds
# Epoch 12, Loss: 0.2148, Val Acc: 0.9256, Training time: 4.4470 seconds
# Epoch 13, Loss: 0.2120, Val Acc: 0.9239, Training time: 4.3720 seconds
# Epoch 14, Loss: 0.2110, Val Acc: 0.9254, Training time: 4.4070 seconds
# Epoch 15, Loss: 0.2085, Val Acc: 0.9259, Training time: 4.3830 seconds
# Epoch 16, Loss: 0.2066, Val Acc: 0.9268, Training time: 4.4160 seconds
# Epoch 17, Loss: 0.2068, Val Acc: 0.9264, Training time: 4.5890 seconds
# Epoch 18, Loss: 0.2042, Val Acc: 0.9264, Training time: 4.9680 seconds
# Epoch 19, Loss: 0.2024, Val Acc: 0.9271, Training time: 5.5080 seconds
# Total Time: 88.83502411842346 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.005, 'num_hidden_layers': 3}
# Epoch 0, Loss: 1.1476, Val Acc: 0.8508, Training time: 5.3600 seconds
# Epoch 1, Loss: 0.4246, Val Acc: 0.8864, Training time: 5.2820 seconds
# Epoch 2, Loss: 0.3272, Val Acc: 0.9041, Training time: 5.2610 seconds
# Epoch 3, Loss: 0.2823, Val Acc: 0.9129, Training time: 5.3150 seconds
# Epoch 4, Loss: 0.2598, Val Acc: 0.9161, Training time: 5.4040 seconds
# Epoch 5, Loss: 0.2475, Val Acc: 0.9184, Training time: 5.5850 seconds
# Epoch 6, Loss: 0.2406, Val Acc: 0.9177, Training time: 5.2530 seconds
# Epoch 7, Loss: 0.2341, Val Acc: 0.9186, Training time: 5.4070 seconds
# Epoch 8, Loss: 0.2294, Val Acc: 0.9192, Training time: 5.2670 seconds
# Epoch 9, Loss: 0.2267, Val Acc: 0.9210, Training time: 5.3210 seconds
# Epoch 10, Loss: 0.2232, Val Acc: 0.9223, Training time: 5.2910 seconds
# Epoch 11, Loss: 0.2190, Val Acc: 0.9233, Training time: 5.3470 seconds
# Epoch 12, Loss: 0.2188, Val Acc: 0.9226, Training time: 5.2300 seconds
# Epoch 13, Loss: 0.2137, Val Acc: 0.9211, Training time: 5.3960 seconds
# Epoch 14, Loss: 0.2115, Val Acc: 0.9253, Training time: 5.2960 seconds
# Epoch 15, Loss: 0.2100, Val Acc: 0.9257, Training time: 5.5190 seconds
# Epoch 16, Loss: 0.2078, Val Acc: 0.9251, Training time: 5.2940 seconds
# Epoch 17, Loss: 0.2073, Val Acc: 0.9252, Training time: 5.3960 seconds
# Epoch 18, Loss: 0.2060, Val Acc: 0.9251, Training time: 5.3920 seconds
# Epoch 19, Loss: 0.2040, Val Acc: 0.9280, Training time: 5.3250 seconds
# Total Time: 106.94102931022644 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.005, 'num_hidden_layers': 4}
# Epoch 0, Loss: 1.1424, Val Acc: 0.8516, Training time: 6.3040 seconds
# Epoch 1, Loss: 0.4209, Val Acc: 0.8869, Training time: 6.2340 seconds
# Epoch 2, Loss: 0.3218, Val Acc: 0.9042, Training time: 6.2470 seconds
# Epoch 3, Loss: 0.2824, Val Acc: 0.9088, Training time: 6.4120 seconds
# Epoch 4, Loss: 0.2640, Val Acc: 0.9146, Training time: 6.2440 seconds
# Epoch 5, Loss: 0.2522, Val Acc: 0.9191, Training time: 6.2800 seconds
# Epoch 6, Loss: 0.2424, Val Acc: 0.9199, Training time: 6.2250 seconds
# Epoch 7, Loss: 0.2378, Val Acc: 0.9202, Training time: 6.2660 seconds
# Epoch 8, Loss: 0.2330, Val Acc: 0.9226, Training time: 6.3390 seconds
# Epoch 9, Loss: 0.2264, Val Acc: 0.9231, Training time: 6.4450 seconds
# Epoch 10, Loss: 0.2244, Val Acc: 0.9221, Training time: 6.1950 seconds
# Epoch 11, Loss: 0.2202, Val Acc: 0.9233, Training time: 6.3160 seconds
# Epoch 12, Loss: 0.2176, Val Acc: 0.9237, Training time: 6.2430 seconds
# Epoch 13, Loss: 0.2146, Val Acc: 0.9255, Training time: 6.3270 seconds
# Epoch 14, Loss: 0.2124, Val Acc: 0.9239, Training time: 6.2780 seconds
# Epoch 15, Loss: 0.2102, Val Acc: 0.9225, Training time: 6.3380 seconds
# Epoch 16, Loss: 0.2078, Val Acc: 0.9252, Training time: 6.2920 seconds
# Epoch 17, Loss: 0.2071, Val Acc: 0.9265, Training time: 6.3520 seconds
# Epoch 18, Loss: 0.2047, Val Acc: 0.9245, Training time: 6.2570 seconds
# Epoch 19, Loss: 0.2032, Val Acc: 0.9268, Training time: 6.2740 seconds
# Total Time: 125.86803579330444 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.005, 'num_hidden_layers': 5}
# Epoch 0, Loss: 1.4207, Val Acc: 0.8285, Training time: 7.1510 seconds
# Epoch 1, Loss: 0.4544, Val Acc: 0.8927, Training time: 7.3440 seconds
# Epoch 2, Loss: 0.3276, Val Acc: 0.9035, Training time: 7.1770 seconds
# Epoch 3, Loss: 0.2864, Val Acc: 0.9073, Training time: 7.2460 seconds
# Epoch 4, Loss: 0.2643, Val Acc: 0.9137, Training time: 7.1860 seconds
# Epoch 5, Loss: 0.2507, Val Acc: 0.9136, Training time: 7.2240 seconds
# Epoch 6, Loss: 0.2410, Val Acc: 0.9169, Training time: 7.3220 seconds
# Epoch 7, Loss: 0.2359, Val Acc: 0.9180, Training time: 7.2320 seconds
# Epoch 8, Loss: 0.2283, Val Acc: 0.9190, Training time: 7.1380 seconds
# Epoch 9, Loss: 0.2253, Val Acc: 0.9205, Training time: 7.1890 seconds
# Epoch 10, Loss: 0.2222, Val Acc: 0.9209, Training time: 7.1770 seconds
# Epoch 11, Loss: 0.2189, Val Acc: 0.9193, Training time: 7.1860 seconds
# Epoch 12, Loss: 0.2151, Val Acc: 0.9210, Training time: 7.3510 seconds
# Epoch 13, Loss: 0.2130, Val Acc: 0.9216, Training time: 7.1810 seconds
# Epoch 14, Loss: 0.2123, Val Acc: 0.9230, Training time: 7.2640 seconds
# Epoch 15, Loss: 0.2101, Val Acc: 0.9238, Training time: 8.0700 seconds
# Epoch 16, Loss: 0.2079, Val Acc: 0.9235, Training time: 7.1040 seconds
# Epoch 17, Loss: 0.2051, Val Acc: 0.9243, Training time: 7.1780 seconds
# Epoch 18, Loss: 0.2042, Val Acc: 0.9248, Training time: 7.1260 seconds
# Epoch 19, Loss: 0.2008, Val Acc: 0.9246, Training time: 7.2130 seconds
# Total Time: 145.05903887748718 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.001, 'num_hidden_layers': 2}
# Epoch 0, Loss: 0.9345, Val Acc: 0.8731, Training time: 4.3930 seconds
# Epoch 1, Loss: 0.3638, Val Acc: 0.8909, Training time: 4.4330 seconds
# Epoch 2, Loss: 0.2952, Val Acc: 0.9080, Training time: 4.4110 seconds
# Epoch 3, Loss: 0.2659, Val Acc: 0.9069, Training time: 4.3690 seconds
# Epoch 4, Loss: 0.2525, Val Acc: 0.9176, Training time: 4.4380 seconds
# Epoch 5, Loss: 0.2431, Val Acc: 0.9179, Training time: 4.6540 seconds
# Epoch 6, Loss: 0.2364, Val Acc: 0.9199, Training time: 4.3860 seconds
# Epoch 7, Loss: 0.2320, Val Acc: 0.9191, Training time: 4.5820 seconds
# Epoch 8, Loss: 0.2268, Val Acc: 0.9209, Training time: 4.3200 seconds
# Epoch 9, Loss: 0.2250, Val Acc: 0.9207, Training time: 4.4340 seconds
# Epoch 10, Loss: 0.2224, Val Acc: 0.9232, Training time: 4.3990 seconds
# Epoch 11, Loss: 0.2193, Val Acc: 0.9227, Training time: 4.3510 seconds
# Epoch 12, Loss: 0.2161, Val Acc: 0.9222, Training time: 4.4940 seconds
# Epoch 13, Loss: 0.2153, Val Acc: 0.9241, Training time: 4.3870 seconds
# Epoch 14, Loss: 0.2144, Val Acc: 0.9241, Training time: 4.3830 seconds
# Epoch 15, Loss: 0.2113, Val Acc: 0.9255, Training time: 4.3910 seconds
# Epoch 16, Loss: 0.2108, Val Acc: 0.9248, Training time: 4.4170 seconds
# Epoch 17, Loss: 0.2085, Val Acc: 0.9244, Training time: 4.3900 seconds
# Epoch 18, Loss: 0.2073, Val Acc: 0.9215, Training time: 4.4030 seconds
# Epoch 19, Loss: 0.2065, Val Acc: 0.9247, Training time: 4.4590 seconds
# Total Time: 88.49402594566345 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.001, 'num_hidden_layers': 3}
# Epoch 0, Loss: 1.0871, Val Acc: 0.8614, Training time: 6.1580 seconds
# Epoch 1, Loss: 0.4056, Val Acc: 0.8886, Training time: 5.2620 seconds
# Epoch 2, Loss: 0.3204, Val Acc: 0.9010, Training time: 5.3110 seconds
# Epoch 3, Loss: 0.2858, Val Acc: 0.9066, Training time: 5.2620 seconds
# Epoch 4, Loss: 0.2607, Val Acc: 0.9101, Training time: 5.3390 seconds
# Epoch 5, Loss: 0.2475, Val Acc: 0.9125, Training time: 5.5320 seconds
# Epoch 6, Loss: 0.2394, Val Acc: 0.9170, Training time: 5.4060 seconds
# Epoch 7, Loss: 0.2337, Val Acc: 0.9176, Training time: 5.4060 seconds
# Epoch 8, Loss: 0.2292, Val Acc: 0.9210, Training time: 5.2990 seconds
# Epoch 9, Loss: 0.2260, Val Acc: 0.9204, Training time: 5.2600 seconds
# Epoch 10, Loss: 0.2221, Val Acc: 0.9195, Training time: 5.3220 seconds
# Epoch 11, Loss: 0.2198, Val Acc: 0.9211, Training time: 5.3850 seconds
# Epoch 12, Loss: 0.2155, Val Acc: 0.9201, Training time: 5.2730 seconds
# Epoch 13, Loss: 0.2137, Val Acc: 0.9233, Training time: 5.3100 seconds
# Epoch 14, Loss: 0.2121, Val Acc: 0.9240, Training time: 5.3290 seconds
# Epoch 15, Loss: 0.2109, Val Acc: 0.9241, Training time: 5.2920 seconds
# Epoch 16, Loss: 0.2111, Val Acc: 0.9242, Training time: 5.3340 seconds
# Epoch 17, Loss: 0.2074, Val Acc: 0.9247, Training time: 5.2840 seconds
# Epoch 18, Loss: 0.2057, Val Acc: 0.9253, Training time: 5.4060 seconds
# Epoch 19, Loss: 0.2027, Val Acc: 0.9257, Training time: 5.2980 seconds
# Total Time: 107.46803045272827 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.001, 'num_hidden_layers': 4}
# Epoch 0, Loss: 1.1317, Val Acc: 0.8435, Training time: 6.4230 seconds
# Epoch 1, Loss: 0.4440, Val Acc: 0.8863, Training time: 6.2470 seconds
# Epoch 2, Loss: 0.3251, Val Acc: 0.8999, Training time: 6.2490 seconds
# Epoch 3, Loss: 0.2816, Val Acc: 0.9099, Training time: 6.2340 seconds
# Epoch 4, Loss: 0.2601, Val Acc: 0.9127, Training time: 6.2980 seconds
# Epoch 5, Loss: 0.2471, Val Acc: 0.9154, Training time: 6.1680 seconds
# Epoch 6, Loss: 0.2389, Val Acc: 0.9167, Training time: 6.2130 seconds
# Epoch 7, Loss: 0.2314, Val Acc: 0.9210, Training time: 6.2150 seconds
# Epoch 8, Loss: 0.2279, Val Acc: 0.9180, Training time: 6.2630 seconds
# Epoch 9, Loss: 0.2237, Val Acc: 0.9219, Training time: 6.3140 seconds
# Epoch 10, Loss: 0.2197, Val Acc: 0.9211, Training time: 6.3940 seconds
# Epoch 11, Loss: 0.2164, Val Acc: 0.9242, Training time: 6.2380 seconds
# Epoch 12, Loss: 0.2125, Val Acc: 0.9237, Training time: 6.2810 seconds
# Epoch 13, Loss: 0.2106, Val Acc: 0.9250, Training time: 6.4470 seconds
# Epoch 14, Loss: 0.2091, Val Acc: 0.9264, Training time: 6.2220 seconds
# Epoch 15, Loss: 0.2050, Val Acc: 0.9242, Training time: 6.4320 seconds
# Epoch 16, Loss: 0.2053, Val Acc: 0.9274, Training time: 6.2210 seconds
# Epoch 17, Loss: 0.2018, Val Acc: 0.9285, Training time: 6.2270 seconds
# Epoch 18, Loss: 0.2006, Val Acc: 0.9251, Training time: 6.7390 seconds
# Epoch 19, Loss: 0.1997, Val Acc: 0.9271, Training time: 6.6440 seconds
# Total Time: 126.46903419494629 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 16, 'learning_rate': 0.001, 'num_hidden_layers': 5}
# Epoch 0, Loss: 1.1563, Val Acc: 0.8208, Training time: 7.5170 seconds
# Epoch 1, Loss: 0.4890, Val Acc: 0.8767, Training time: 7.4110 seconds
# Epoch 2, Loss: 0.3554, Val Acc: 0.8991, Training time: 7.1980 seconds
# Epoch 3, Loss: 0.3013, Val Acc: 0.9082, Training time: 7.7140 seconds
# Epoch 4, Loss: 0.2734, Val Acc: 0.9110, Training time: 7.5300 seconds
# Epoch 5, Loss: 0.2576, Val Acc: 0.9127, Training time: 7.3770 seconds
# Epoch 6, Loss: 0.2449, Val Acc: 0.9193, Training time: 7.2120 seconds
# Epoch 7, Loss: 0.2359, Val Acc: 0.9200, Training time: 7.1900 seconds
# Epoch 8, Loss: 0.2293, Val Acc: 0.9206, Training time: 7.1920 seconds
# Epoch 9, Loss: 0.2257, Val Acc: 0.9201, Training time: 7.1910 seconds
# Epoch 10, Loss: 0.2208, Val Acc: 0.9222, Training time: 7.1980 seconds
# Epoch 11, Loss: 0.2175, Val Acc: 0.9233, Training time: 7.2720 seconds
# Epoch 12, Loss: 0.2151, Val Acc: 0.9240, Training time: 7.2530 seconds
# Epoch 13, Loss: 0.2128, Val Acc: 0.9253, Training time: 7.1570 seconds
# Epoch 14, Loss: 0.2106, Val Acc: 0.9242, Training time: 7.1930 seconds
# Epoch 15, Loss: 0.2088, Val Acc: 0.9269, Training time: 7.2040 seconds
# Epoch 16, Loss: 0.2064, Val Acc: 0.9271, Training time: 7.2440 seconds
# Epoch 17, Loss: 0.2066, Val Acc: 0.9271, Training time: 7.3430 seconds
# Epoch 18, Loss: 0.2039, Val Acc: 0.9251, Training time: 7.2700 seconds
# Epoch 19, Loss: 0.2020, Val Acc: 0.9274, Training time: 7.2940 seconds
# Total Time: 145.96003937721252 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.01, 'num_hidden_layers': 2}
# Epoch 0, Loss: 0.6373, Val Acc: 0.8938, Training time: 5.0530 seconds
# Epoch 1, Loss: 0.2896, Val Acc: 0.9087, Training time: 4.9780 seconds
# Epoch 2, Loss: 0.2511, Val Acc: 0.9185, Training time: 4.9730 seconds
# Epoch 3, Loss: 0.2337, Val Acc: 0.9203, Training time: 5.0040 seconds
# Epoch 4, Loss: 0.2238, Val Acc: 0.9214, Training time: 5.0350 seconds
# Epoch 5, Loss: 0.2167, Val Acc: 0.9224, Training time: 4.9860 seconds
# Epoch 6, Loss: 0.2113, Val Acc: 0.9247, Training time: 4.9290 seconds
# Epoch 7, Loss: 0.2047, Val Acc: 0.9262, Training time: 4.9860 seconds
# Epoch 8, Loss: 0.2024, Val Acc: 0.9255, Training time: 4.9940 seconds
# Epoch 9, Loss: 0.1981, Val Acc: 0.9257, Training time: 5.0840 seconds
# Epoch 10, Loss: 0.1966, Val Acc: 0.9296, Training time: 5.0040 seconds
# Epoch 11, Loss: 0.1923, Val Acc: 0.9290, Training time: 5.1310 seconds
# Epoch 12, Loss: 0.1913, Val Acc: 0.9310, Training time: 5.0260 seconds
# Epoch 13, Loss: 0.1881, Val Acc: 0.9298, Training time: 5.0340 seconds
# Epoch 14, Loss: 0.1865, Val Acc: 0.9305, Training time: 5.1600 seconds
# Epoch 15, Loss: 0.1841, Val Acc: 0.9320, Training time: 5.0490 seconds
# Epoch 16, Loss: 0.1829, Val Acc: 0.9321, Training time: 5.2180 seconds
# Epoch 17, Loss: 0.1818, Val Acc: 0.9320, Training time: 5.1590 seconds
# Epoch 18, Loss: 0.1784, Val Acc: 0.9317, Training time: 5.0740 seconds
# Epoch 19, Loss: 0.1776, Val Acc: 0.9325, Training time: 5.1380 seconds
# Total Time: 101.01502561569214 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.01, 'num_hidden_layers': 3}
# Epoch 0, Loss: 0.7272, Val Acc: 0.8928, Training time: 6.2710 seconds
# Epoch 1, Loss: 0.2899, Val Acc: 0.9083, Training time: 6.4290 seconds
# Epoch 2, Loss: 0.2483, Val Acc: 0.9192, Training time: 6.4250 seconds
# Epoch 3, Loss: 0.2300, Val Acc: 0.9217, Training time: 6.1460 seconds
# Epoch 4, Loss: 0.2200, Val Acc: 0.9245, Training time: 6.2160 seconds
# Epoch 5, Loss: 0.2105, Val Acc: 0.9261, Training time: 6.1680 seconds
# Epoch 6, Loss: 0.2066, Val Acc: 0.9280, Training time: 6.2640 seconds
# Epoch 7, Loss: 0.2023, Val Acc: 0.9280, Training time: 6.1680 seconds
# Epoch 8, Loss: 0.1985, Val Acc: 0.9279, Training time: 6.2080 seconds
# Epoch 9, Loss: 0.1939, Val Acc: 0.9295, Training time: 6.1820 seconds
# Epoch 10, Loss: 0.1899, Val Acc: 0.9317, Training time: 6.1700 seconds
# Epoch 11, Loss: 0.1860, Val Acc: 0.9316, Training time: 6.4100 seconds
# Epoch 12, Loss: 0.1851, Val Acc: 0.9321, Training time: 6.1210 seconds
# Epoch 13, Loss: 0.1812, Val Acc: 0.9322, Training time: 6.3750 seconds
# Epoch 14, Loss: 0.1792, Val Acc: 0.9343, Training time: 6.2730 seconds
# Epoch 15, Loss: 0.1769, Val Acc: 0.9335, Training time: 6.3620 seconds
# Epoch 16, Loss: 0.1763, Val Acc: 0.9342, Training time: 6.2990 seconds
# Epoch 17, Loss: 0.1728, Val Acc: 0.9345, Training time: 6.1490 seconds
# Epoch 18, Loss: 0.1711, Val Acc: 0.9335, Training time: 6.2280 seconds
# Epoch 19, Loss: 0.1701, Val Acc: 0.9339, Training time: 6.1950 seconds
# Total Time: 125.05903387069702 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.01, 'num_hidden_layers': 4}
# Epoch 0, Loss: 0.7134, Val Acc: 0.8884, Training time: 7.4400 seconds
# Epoch 1, Loss: 0.3040, Val Acc: 0.9122, Training time: 7.3050 seconds
# Epoch 2, Loss: 0.2550, Val Acc: 0.9181, Training time: 7.4520 seconds
# Epoch 3, Loss: 0.2362, Val Acc: 0.9193, Training time: 7.3240 seconds
# Epoch 4, Loss: 0.2252, Val Acc: 0.9197, Training time: 7.4050 seconds
# Epoch 5, Loss: 0.2158, Val Acc: 0.9236, Training time: 7.4750 seconds
# Epoch 6, Loss: 0.2085, Val Acc: 0.9236, Training time: 7.2880 seconds
# Epoch 7, Loss: 0.2034, Val Acc: 0.9259, Training time: 7.3070 seconds
# Epoch 8, Loss: 0.1994, Val Acc: 0.9253, Training time: 7.2760 seconds
# Epoch 9, Loss: 0.1950, Val Acc: 0.9278, Training time: 7.4660 seconds
# Epoch 10, Loss: 0.1922, Val Acc: 0.9282, Training time: 7.2600 seconds
# Epoch 11, Loss: 0.1869, Val Acc: 0.9284, Training time: 7.3870 seconds
# Epoch 12, Loss: 0.1828, Val Acc: 0.9288, Training time: 7.4020 seconds
# Epoch 13, Loss: 0.1803, Val Acc: 0.9324, Training time: 7.3400 seconds
# Epoch 14, Loss: 0.1792, Val Acc: 0.9303, Training time: 7.3750 seconds
# Epoch 15, Loss: 0.1760, Val Acc: 0.9324, Training time: 7.3630 seconds
# Epoch 16, Loss: 0.1733, Val Acc: 0.9321, Training time: 7.2930 seconds
# Epoch 17, Loss: 0.1710, Val Acc: 0.9329, Training time: 7.3980 seconds
# Epoch 18, Loss: 0.1687, Val Acc: 0.9332, Training time: 7.5370 seconds
# Epoch 19, Loss: 0.1662, Val Acc: 0.9346, Training time: 7.3650 seconds
# Total Time: 147.45803570747375 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.01, 'num_hidden_layers': 5}
# Epoch 0, Loss: 0.8990, Val Acc: 0.8781, Training time: 9.0760 seconds
# Epoch 1, Loss: 0.3377, Val Acc: 0.9073, Training time: 8.4820 seconds
# Epoch 2, Loss: 0.2627, Val Acc: 0.9154, Training time: 8.5080 seconds
# Epoch 3, Loss: 0.2341, Val Acc: 0.9189, Training time: 8.6980 seconds
# Epoch 4, Loss: 0.2238, Val Acc: 0.9244, Training time: 8.5870 seconds
# Epoch 5, Loss: 0.2134, Val Acc: 0.9255, Training time: 8.4920 seconds
# Epoch 6, Loss: 0.2071, Val Acc: 0.9273, Training time: 8.4220 seconds
# Epoch 7, Loss: 0.2020, Val Acc: 0.9280, Training time: 8.4390 seconds
# Epoch 8, Loss: 0.1952, Val Acc: 0.9295, Training time: 8.5300 seconds
# Epoch 9, Loss: 0.1926, Val Acc: 0.9302, Training time: 8.4380 seconds
# Epoch 10, Loss: 0.1891, Val Acc: 0.9302, Training time: 8.6370 seconds
# Epoch 11, Loss: 0.1861, Val Acc: 0.9335, Training time: 8.5690 seconds
# Epoch 12, Loss: 0.1840, Val Acc: 0.9325, Training time: 8.5240 seconds
# Epoch 13, Loss: 0.1796, Val Acc: 0.9331, Training time: 8.4670 seconds
# Epoch 14, Loss: 0.1787, Val Acc: 0.9342, Training time: 8.5690 seconds
# Epoch 15, Loss: 0.1758, Val Acc: 0.9339, Training time: 8.5750 seconds
# Epoch 16, Loss: 0.1740, Val Acc: 0.9341, Training time: 8.5990 seconds
# Epoch 17, Loss: 0.1712, Val Acc: 0.9310, Training time: 9.2430 seconds
# Epoch 18, Loss: 0.1687, Val Acc: 0.9361, Training time: 8.5650 seconds
# Epoch 19, Loss: 0.1665, Val Acc: 0.9352, Training time: 8.5780 seconds
# Total Time: 171.99805068969727 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.005, 'num_hidden_layers': 2}
# Epoch 0, Loss: 0.5900, Val Acc: 0.8953, Training time: 5.0940 seconds
# Epoch 1, Loss: 0.2838, Val Acc: 0.9110, Training time: 5.0380 seconds
# Epoch 2, Loss: 0.2441, Val Acc: 0.9185, Training time: 5.1840 seconds
# Epoch 3, Loss: 0.2283, Val Acc: 0.9208, Training time: 4.9680 seconds
# Epoch 4, Loss: 0.2200, Val Acc: 0.9238, Training time: 5.0360 seconds
# Epoch 5, Loss: 0.2123, Val Acc: 0.9245, Training time: 5.0110 seconds
# Epoch 6, Loss: 0.2087, Val Acc: 0.9271, Training time: 5.0040 seconds
# Epoch 7, Loss: 0.2028, Val Acc: 0.9274, Training time: 5.0190 seconds
# Epoch 8, Loss: 0.1999, Val Acc: 0.9244, Training time: 5.1040 seconds
# Epoch 9, Loss: 0.1964, Val Acc: 0.9278, Training time: 4.9920 seconds
# Epoch 10, Loss: 0.1934, Val Acc: 0.9293, Training time: 4.9760 seconds
# Epoch 11, Loss: 0.1897, Val Acc: 0.9285, Training time: 4.9890 seconds
# Epoch 12, Loss: 0.1871, Val Acc: 0.9298, Training time: 5.0070 seconds
# Epoch 13, Loss: 0.1862, Val Acc: 0.9297, Training time: 4.9920 seconds
# Epoch 14, Loss: 0.1845, Val Acc: 0.9291, Training time: 5.1190 seconds
# Epoch 15, Loss: 0.1830, Val Acc: 0.9329, Training time: 5.0280 seconds
# Epoch 16, Loss: 0.1802, Val Acc: 0.9321, Training time: 4.9770 seconds
# Epoch 17, Loss: 0.1804, Val Acc: 0.9318, Training time: 5.0020 seconds
# Epoch 18, Loss: 0.1781, Val Acc: 0.9334, Training time: 5.0620 seconds
# Epoch 19, Loss: 0.1771, Val Acc: 0.9323, Training time: 5.0550 seconds
# Total Time: 100.65702629089355 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.005, 'num_hidden_layers': 3}
# Epoch 0, Loss: 0.7288, Val Acc: 0.8939, Training time: 6.2420 seconds
# Epoch 1, Loss: 0.2956, Val Acc: 0.9099, Training time: 6.3580 seconds
# Epoch 2, Loss: 0.2517, Val Acc: 0.9180, Training time: 6.1080 seconds
# Epoch 3, Loss: 0.2335, Val Acc: 0.9205, Training time: 6.3450 seconds
# Epoch 4, Loss: 0.2212, Val Acc: 0.9234, Training time: 6.1430 seconds
# Epoch 5, Loss: 0.2122, Val Acc: 0.9259, Training time: 6.3280 seconds
# Epoch 6, Loss: 0.2062, Val Acc: 0.9254, Training time: 6.2110 seconds
# Epoch 7, Loss: 0.2014, Val Acc: 0.9287, Training time: 6.1800 seconds
# Epoch 8, Loss: 0.1971, Val Acc: 0.9292, Training time: 6.1380 seconds
# Epoch 9, Loss: 0.1941, Val Acc: 0.9267, Training time: 6.1620 seconds
# Epoch 10, Loss: 0.1907, Val Acc: 0.9295, Training time: 6.1770 seconds
# Epoch 11, Loss: 0.1875, Val Acc: 0.9300, Training time: 6.1760 seconds
# Epoch 12, Loss: 0.1844, Val Acc: 0.9306, Training time: 6.2360 seconds
# Epoch 13, Loss: 0.1832, Val Acc: 0.9313, Training time: 6.1980 seconds
# Epoch 14, Loss: 0.1821, Val Acc: 0.9314, Training time: 6.2880 seconds
# Epoch 15, Loss: 0.1772, Val Acc: 0.9325, Training time: 6.2730 seconds
# Epoch 16, Loss: 0.1759, Val Acc: 0.9320, Training time: 6.1750 seconds
# Epoch 17, Loss: 0.1747, Val Acc: 0.9328, Training time: 6.3500 seconds
# Epoch 18, Loss: 0.1726, Val Acc: 0.9328, Training time: 6.2400 seconds
# Epoch 19, Loss: 0.1703, Val Acc: 0.9284, Training time: 6.2050 seconds
# Total Time: 124.53303575515747 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.005, 'num_hidden_layers': 4}
# Epoch 0, Loss: 0.7698, Val Acc: 0.8879, Training time: 7.4440 seconds
# Epoch 1, Loss: 0.3053, Val Acc: 0.9107, Training time: 7.2770 seconds
# Epoch 2, Loss: 0.2530, Val Acc: 0.9165, Training time: 7.3590 seconds
# Epoch 3, Loss: 0.2336, Val Acc: 0.9198, Training time: 7.2930 seconds
# Epoch 4, Loss: 0.2208, Val Acc: 0.9249, Training time: 7.3870 seconds
# Epoch 5, Loss: 0.2126, Val Acc: 0.9243, Training time: 7.3110 seconds
# Epoch 6, Loss: 0.2045, Val Acc: 0.9258, Training time: 7.3400 seconds
# Epoch 7, Loss: 0.2022, Val Acc: 0.9246, Training time: 7.3170 seconds
# Epoch 8, Loss: 0.1952, Val Acc: 0.9285, Training time: 7.2850 seconds
# Epoch 9, Loss: 0.1899, Val Acc: 0.9288, Training time: 7.3390 seconds
# Epoch 10, Loss: 0.1869, Val Acc: 0.9292, Training time: 7.9890 seconds
# Epoch 11, Loss: 0.1850, Val Acc: 0.9306, Training time: 9.4670 seconds
# Epoch 12, Loss: 0.1802, Val Acc: 0.9316, Training time: 9.1460 seconds
# Epoch 13, Loss: 0.1775, Val Acc: 0.9292, Training time: 10.7780 seconds
# Epoch 14, Loss: 0.1745, Val Acc: 0.9315, Training time: 8.8970 seconds
# Epoch 15, Loss: 0.1748, Val Acc: 0.9298, Training time: 7.7010 seconds
# Epoch 16, Loss: 0.1722, Val Acc: 0.9320, Training time: 7.6300 seconds
# Epoch 17, Loss: 0.1676, Val Acc: 0.9306, Training time: 7.6650 seconds
# Epoch 18, Loss: 0.1674, Val Acc: 0.9326, Training time: 7.6800 seconds
# Epoch 19, Loss: 0.1664, Val Acc: 0.9364, Training time: 7.6030 seconds
# Total Time: 157.90804195404053 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.005, 'num_hidden_layers': 5}
# Epoch 0, Loss: 0.8625, Val Acc: 0.8901, Training time: 9.0630 seconds
# Epoch 1, Loss: 0.3118, Val Acc: 0.9124, Training time: 8.4710 seconds
# Epoch 2, Loss: 0.2571, Val Acc: 0.9193, Training time: 8.4510 seconds
# Epoch 3, Loss: 0.2328, Val Acc: 0.9215, Training time: 8.8790 seconds
# Epoch 4, Loss: 0.2199, Val Acc: 0.9251, Training time: 8.3520 seconds
# Epoch 5, Loss: 0.2108, Val Acc: 0.9273, Training time: 8.4980 seconds
# Epoch 6, Loss: 0.2035, Val Acc: 0.9255, Training time: 8.3580 seconds
# Epoch 7, Loss: 0.1971, Val Acc: 0.9271, Training time: 8.5310 seconds
# Epoch 8, Loss: 0.1940, Val Acc: 0.9288, Training time: 8.3690 seconds
# Epoch 9, Loss: 0.1888, Val Acc: 0.9308, Training time: 8.4580 seconds
# Epoch 10, Loss: 0.1863, Val Acc: 0.9303, Training time: 8.3910 seconds
# Epoch 11, Loss: 0.1823, Val Acc: 0.9303, Training time: 8.4480 seconds
# Epoch 12, Loss: 0.1777, Val Acc: 0.9302, Training time: 8.3320 seconds
# Epoch 13, Loss: 0.1770, Val Acc: 0.9326, Training time: 8.5360 seconds
# Epoch 14, Loss: 0.1743, Val Acc: 0.9330, Training time: 8.5650 seconds
# Epoch 15, Loss: 0.1738, Val Acc: 0.9344, Training time: 8.4350 seconds
# Epoch 16, Loss: 0.1702, Val Acc: 0.9353, Training time: 8.4520 seconds
# Epoch 17, Loss: 0.1666, Val Acc: 0.9333, Training time: 8.4220 seconds
# Epoch 18, Loss: 0.1657, Val Acc: 0.9362, Training time: 8.3700 seconds
# Epoch 19, Loss: 0.1646, Val Acc: 0.9366, Training time: 8.4170 seconds
# Total Time: 169.7980432510376 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.001, 'num_hidden_layers': 2}
# Epoch 0, Loss: 0.6068, Val Acc: 0.8975, Training time: 5.0400 seconds
# Epoch 1, Loss: 0.2806, Val Acc: 0.9122, Training time: 4.9200 seconds
# Epoch 2, Loss: 0.2467, Val Acc: 0.9165, Training time: 4.9470 seconds
# Epoch 3, Loss: 0.2339, Val Acc: 0.9191, Training time: 5.0310 seconds
# Epoch 4, Loss: 0.2249, Val Acc: 0.9223, Training time: 4.9270 seconds
# Epoch 5, Loss: 0.2185, Val Acc: 0.9247, Training time: 4.9450 seconds
# Epoch 6, Loss: 0.2136, Val Acc: 0.9229, Training time: 5.0140 seconds
# Epoch 7, Loss: 0.2094, Val Acc: 0.9247, Training time: 4.9520 seconds
# Epoch 8, Loss: 0.2044, Val Acc: 0.9251, Training time: 4.9230 seconds
# Epoch 9, Loss: 0.2012, Val Acc: 0.9255, Training time: 4.9890 seconds
# Epoch 10, Loss: 0.1979, Val Acc: 0.9292, Training time: 5.1190 seconds
# Epoch 11, Loss: 0.1957, Val Acc: 0.9272, Training time: 5.0430 seconds
# Epoch 12, Loss: 0.1944, Val Acc: 0.9309, Training time: 4.9710 seconds
# Epoch 13, Loss: 0.1905, Val Acc: 0.9297, Training time: 4.9900 seconds
# Epoch 14, Loss: 0.1886, Val Acc: 0.9312, Training time: 4.9240 seconds
# Epoch 15, Loss: 0.1869, Val Acc: 0.9315, Training time: 4.9680 seconds
# Epoch 16, Loss: 0.1854, Val Acc: 0.9313, Training time: 5.4760 seconds
# Epoch 17, Loss: 0.1822, Val Acc: 0.9324, Training time: 5.0350 seconds
# Epoch 18, Loss: 0.1786, Val Acc: 0.9320, Training time: 4.9920 seconds
# Epoch 19, Loss: 0.1786, Val Acc: 0.9320, Training time: 5.0810 seconds
# Total Time: 100.28702712059021 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.001, 'num_hidden_layers': 3}
# Epoch 0, Loss: 0.8312, Val Acc: 0.8862, Training time: 6.2110 seconds
# Epoch 1, Loss: 0.3273, Val Acc: 0.9075, Training time: 6.1300 seconds
# Epoch 2, Loss: 0.2597, Val Acc: 0.9157, Training time: 6.1590 seconds
# Epoch 3, Loss: 0.2378, Val Acc: 0.9199, Training time: 6.1020 seconds
# Epoch 4, Loss: 0.2237, Val Acc: 0.9223, Training time: 6.0920 seconds
# Epoch 5, Loss: 0.2144, Val Acc: 0.9214, Training time: 6.0960 seconds
# Epoch 6, Loss: 0.2080, Val Acc: 0.9249, Training time: 6.1490 seconds
# Epoch 7, Loss: 0.2024, Val Acc: 0.9266, Training time: 6.1310 seconds
# Epoch 8, Loss: 0.1984, Val Acc: 0.9278, Training time: 6.2130 seconds
# Epoch 9, Loss: 0.1934, Val Acc: 0.9266, Training time: 6.4380 seconds
# Epoch 10, Loss: 0.1895, Val Acc: 0.9278, Training time: 6.1140 seconds
# Epoch 11, Loss: 0.1851, Val Acc: 0.9271, Training time: 6.1160 seconds
# Epoch 12, Loss: 0.1838, Val Acc: 0.9318, Training time: 6.1900 seconds
# Epoch 13, Loss: 0.1809, Val Acc: 0.9309, Training time: 6.1500 seconds
# Epoch 14, Loss: 0.1802, Val Acc: 0.9313, Training time: 6.0770 seconds
# Epoch 15, Loss: 0.1769, Val Acc: 0.9324, Training time: 6.1650 seconds
# Epoch 16, Loss: 0.1750, Val Acc: 0.9329, Training time: 6.1420 seconds
# Epoch 17, Loss: 0.1729, Val Acc: 0.9343, Training time: 6.1320 seconds
# Epoch 18, Loss: 0.1693, Val Acc: 0.9313, Training time: 6.1580 seconds
# Epoch 19, Loss: 0.1690, Val Acc: 0.9322, Training time: 6.1120 seconds
# Total Time: 123.07703471183777 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.001, 'num_hidden_layers': 4}
# Epoch 0, Loss: 0.6641, Val Acc: 0.8918, Training time: 7.4140 seconds
# Epoch 1, Loss: 0.2866, Val Acc: 0.9091, Training time: 7.2310 seconds
# Epoch 2, Loss: 0.2432, Val Acc: 0.9168, Training time: 7.2150 seconds
# Epoch 3, Loss: 0.2274, Val Acc: 0.9191, Training time: 7.3950 seconds
# Epoch 4, Loss: 0.2184, Val Acc: 0.9214, Training time: 7.3020 seconds
# Epoch 5, Loss: 0.2101, Val Acc: 0.9250, Training time: 7.1770 seconds
# Epoch 6, Loss: 0.2045, Val Acc: 0.9269, Training time: 7.3600 seconds
# Epoch 7, Loss: 0.2025, Val Acc: 0.9276, Training time: 7.2880 seconds
# Epoch 8, Loss: 0.1941, Val Acc: 0.9282, Training time: 7.2000 seconds
# Epoch 9, Loss: 0.1914, Val Acc: 0.9277, Training time: 7.3960 seconds
# Epoch 10, Loss: 0.1884, Val Acc: 0.9292, Training time: 7.2170 seconds
# Epoch 11, Loss: 0.1862, Val Acc: 0.9293, Training time: 7.4800 seconds
# Epoch 12, Loss: 0.1831, Val Acc: 0.9295, Training time: 7.2690 seconds
# Epoch 13, Loss: 0.1812, Val Acc: 0.9325, Training time: 7.8700 seconds
# Epoch 14, Loss: 0.1781, Val Acc: 0.9334, Training time: 7.3240 seconds
# Epoch 15, Loss: 0.1750, Val Acc: 0.9280, Training time: 7.3000 seconds
# Epoch 16, Loss: 0.1747, Val Acc: 0.9334, Training time: 7.4560 seconds
# Epoch 17, Loss: 0.1714, Val Acc: 0.9333, Training time: 7.2350 seconds
# Epoch 18, Loss: 0.1698, Val Acc: 0.9334, Training time: 7.2880 seconds
# Epoch 19, Loss: 0.1663, Val Acc: 0.9334, Training time: 7.3230 seconds
# Total Time: 146.7400417327881 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 32, 'learning_rate': 0.001, 'num_hidden_layers': 5}
# Epoch 0, Loss: 0.8474, Val Acc: 0.8902, Training time: 8.4650 seconds
# Epoch 1, Loss: 0.3088, Val Acc: 0.9095, Training time: 8.3970 seconds
# Epoch 2, Loss: 0.2555, Val Acc: 0.9177, Training time: 8.4660 seconds
# Epoch 3, Loss: 0.2354, Val Acc: 0.9193, Training time: 8.4210 seconds
# Epoch 4, Loss: 0.2232, Val Acc: 0.9236, Training time: 8.3520 seconds
# Epoch 5, Loss: 0.2144, Val Acc: 0.9237, Training time: 8.3950 seconds
# Epoch 6, Loss: 0.2091, Val Acc: 0.9232, Training time: 8.4120 seconds
# Epoch 7, Loss: 0.2012, Val Acc: 0.9254, Training time: 8.3770 seconds
# Epoch 8, Loss: 0.1980, Val Acc: 0.9266, Training time: 8.5780 seconds
# Epoch 9, Loss: 0.1946, Val Acc: 0.9254, Training time: 8.6500 seconds
# Epoch 10, Loss: 0.1903, Val Acc: 0.9274, Training time: 8.4480 seconds
# Epoch 11, Loss: 0.1873, Val Acc: 0.9257, Training time: 8.3860 seconds
# Epoch 12, Loss: 0.1854, Val Acc: 0.9294, Training time: 8.3250 seconds
# Epoch 13, Loss: 0.1802, Val Acc: 0.9292, Training time: 8.3830 seconds
# Epoch 14, Loss: 0.1773, Val Acc: 0.9303, Training time: 8.4200 seconds
# Epoch 15, Loss: 0.1777, Val Acc: 0.9324, Training time: 8.3490 seconds
# Epoch 16, Loss: 0.1727, Val Acc: 0.9272, Training time: 8.4200 seconds
# Epoch 17, Loss: 0.1731, Val Acc: 0.9297, Training time: 8.5070 seconds
# Epoch 18, Loss: 0.1686, Val Acc: 0.9304, Training time: 8.4060 seconds
# Epoch 19, Loss: 0.1672, Val Acc: 0.9323, Training time: 8.6230 seconds
# Total Time: 168.78004789352417 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 64, 'learning_rate': 0.01, 'num_hidden_layers': 2}
# Epoch 0, Loss: 0.4247, Val Acc: 0.9180, Training time: 6.0560 seconds
# Epoch 1, Loss: 0.2348, Val Acc: 0.9249, Training time: 6.0170 seconds
# Epoch 2, Loss: 0.2156, Val Acc: 0.9273, Training time: 5.9870 seconds
# Epoch 3, Loss: 0.2042, Val Acc: 0.9283, Training time: 5.9450 seconds
# Epoch 4, Loss: 0.1987, Val Acc: 0.9304, Training time: 5.9430 seconds
# Epoch 5, Loss: 0.1912, Val Acc: 0.9295, Training time: 5.9010 seconds
# Epoch 6, Loss: 0.1869, Val Acc: 0.9286, Training time: 6.0130 seconds
# Epoch 7, Loss: 0.1826, Val Acc: 0.9333, Training time: 6.1800 seconds
# Epoch 8, Loss: 0.1770, Val Acc: 0.9336, Training time: 5.9180 seconds
# Epoch 9, Loss: 0.1723, Val Acc: 0.9317, Training time: 6.0580 seconds
# Epoch 10, Loss: 0.1717, Val Acc: 0.9307, Training time: 5.9610 seconds
# Epoch 11, Loss: 0.1674, Val Acc: 0.9329, Training time: 6.0140 seconds
# Epoch 12, Loss: 0.1641, Val Acc: 0.9303, Training time: 5.9850 seconds
# Epoch 13, Loss: 0.1615, Val Acc: 0.9359, Training time: 6.0020 seconds
# Epoch 14, Loss: 0.1590, Val Acc: 0.9335, Training time: 5.9750 seconds
# Epoch 15, Loss: 0.1568, Val Acc: 0.9373, Training time: 6.2710 seconds
# Epoch 16, Loss: 0.1531, Val Acc: 0.9327, Training time: 5.9970 seconds
# Epoch 17, Loss: 0.1526, Val Acc: 0.9356, Training time: 6.0620 seconds
# Epoch 18, Loss: 0.1475, Val Acc: 0.9302, Training time: 6.0680 seconds
# Epoch 19, Loss: 0.1476, Val Acc: 0.9364, Training time: 6.1690 seconds
# Total Time: 120.52203321456909 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 64, 'learning_rate': 0.01, 'num_hidden_layers': 3}
# Epoch 0, Loss: 0.4744, Val Acc: 0.9103, Training time: 7.6370 seconds
# Epoch 1, Loss: 0.2385, Val Acc: 0.9216, Training time: 7.3930 seconds
# Epoch 2, Loss: 0.2153, Val Acc: 0.9244, Training time: 7.4650 seconds
# Epoch 3, Loss: 0.2038, Val Acc: 0.9260, Training time: 7.3780 seconds
# Epoch 4, Loss: 0.1956, Val Acc: 0.9284, Training time: 7.4730 seconds
# Epoch 5, Loss: 0.1892, Val Acc: 0.9299, Training time: 7.3760 seconds
# Epoch 6, Loss: 0.1841, Val Acc: 0.9310, Training time: 7.4510 seconds
# Epoch 7, Loss: 0.1778, Val Acc: 0.9311, Training time: 7.5070 seconds
# Epoch 8, Loss: 0.1724, Val Acc: 0.9320, Training time: 7.5340 seconds
# Epoch 9, Loss: 0.1682, Val Acc: 0.9353, Training time: 7.4610 seconds
# Epoch 10, Loss: 0.1642, Val Acc: 0.9343, Training time: 7.4430 seconds
# Epoch 11, Loss: 0.1590, Val Acc: 0.9361, Training time: 7.5140 seconds
# Epoch 12, Loss: 0.1558, Val Acc: 0.9385, Training time: 7.4740 seconds
# Epoch 13, Loss: 0.1534, Val Acc: 0.9360, Training time: 7.4200 seconds
# Epoch 14, Loss: 0.1491, Val Acc: 0.9360, Training time: 7.4250 seconds
# Epoch 15, Loss: 0.1481, Val Acc: 0.9366, Training time: 7.7320 seconds
# Epoch 16, Loss: 0.1463, Val Acc: 0.9365, Training time: 7.7250 seconds
# Epoch 17, Loss: 0.1425, Val Acc: 0.9357, Training time: 7.5030 seconds
# Epoch 18, Loss: 0.1403, Val Acc: 0.9394, Training time: 7.6800 seconds
# Epoch 19, Loss: 0.1359, Val Acc: 0.9375, Training time: 7.4780 seconds
# Total Time: 150.06904292106628 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 64, 'learning_rate': 0.01, 'num_hidden_layers': 4}
# Epoch 0, Loss: 0.4797, Val Acc: 0.9127, Training time: 9.1620 seconds
# Epoch 1, Loss: 0.2354, Val Acc: 0.9255, Training time: 8.8970 seconds
# Epoch 2, Loss: 0.2120, Val Acc: 0.9254, Training time: 8.8350 seconds
# Epoch 3, Loss: 0.2016, Val Acc: 0.9279, Training time: 8.9600 seconds
# Epoch 4, Loss: 0.1920, Val Acc: 0.9304, Training time: 8.9640 seconds
# Epoch 5, Loss: 0.1870, Val Acc: 0.9300, Training time: 8.9310 seconds
# Epoch 6, Loss: 0.1802, Val Acc: 0.9309, Training time: 8.9670 seconds
# Epoch 7, Loss: 0.1738, Val Acc: 0.9313, Training time: 8.9450 seconds
# Epoch 8, Loss: 0.1681, Val Acc: 0.9339, Training time: 8.9680 seconds
# Epoch 9, Loss: 0.1642, Val Acc: 0.9342, Training time: 9.0200 seconds
# Epoch 10, Loss: 0.1600, Val Acc: 0.9343, Training time: 8.9510 seconds
# Epoch 11, Loss: 0.1557, Val Acc: 0.9333, Training time: 9.1140 seconds
# Epoch 12, Loss: 0.1520, Val Acc: 0.9364, Training time: 8.9500 seconds
# Epoch 13, Loss: 0.1485, Val Acc: 0.9358, Training time: 8.9700 seconds
# Epoch 14, Loss: 0.1455, Val Acc: 0.9372, Training time: 8.8920 seconds
# Epoch 15, Loss: 0.1419, Val Acc: 0.9388, Training time: 8.9660 seconds
# Epoch 16, Loss: 0.1400, Val Acc: 0.9362, Training time: 8.9870 seconds
# Epoch 17, Loss: 0.1380, Val Acc: 0.9379, Training time: 9.0730 seconds
# Epoch 18, Loss: 0.1338, Val Acc: 0.9386, Training time: 9.0950 seconds
# Epoch 19, Loss: 0.1301, Val Acc: 0.9366, Training time: 9.0410 seconds
# Total Time: 179.6880488395691 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 64, 'learning_rate': 0.01, 'num_hidden_layers': 5}
# Epoch 0, Loss: 0.5671, Val Acc: 0.9096, Training time: 10.6740 seconds
# Epoch 1, Loss: 0.2471, Val Acc: 0.9171, Training time: 10.5750 seconds
# Epoch 2, Loss: 0.2195, Val Acc: 0.9218, Training time: 10.4130 seconds
# Epoch 3, Loss: 0.2082, Val Acc: 0.9249, Training time: 11.0990 seconds
# Epoch 4, Loss: 0.1950, Val Acc: 0.9278, Training time: 10.5300 seconds
# Epoch 5, Loss: 0.1881, Val Acc: 0.9279, Training time: 10.4560 seconds
# Epoch 6, Loss: 0.1831, Val Acc: 0.9312, Training time: 10.5480 seconds
# Epoch 7, Loss: 0.1747, Val Acc: 0.9307, Training time: 10.4730 seconds
# Epoch 8, Loss: 0.1695, Val Acc: 0.9318, Training time: 10.7860 seconds
# Epoch 9, Loss: 0.1641, Val Acc: 0.9332, Training time: 10.7480 seconds
# Epoch 10, Loss: 0.1606, Val Acc: 0.9333, Training time: 10.5270 seconds
# Epoch 11, Loss: 0.1588, Val Acc: 0.9337, Training time: 10.5150 seconds
# Epoch 12, Loss: 0.1548, Val Acc: 0.9366, Training time: 10.9580 seconds
# Epoch 13, Loss: 0.1507, Val Acc: 0.9369, Training time: 10.3760 seconds
# Epoch 14, Loss: 0.1509, Val Acc: 0.9384, Training time: 10.4330 seconds
# Epoch 15, Loss: 0.1446, Val Acc: 0.9399, Training time: 10.4900 seconds
# Epoch 16, Loss: 0.1404, Val Acc: 0.9371, Training time: 10.4190 seconds
# Epoch 17, Loss: 0.1380, Val Acc: 0.9402, Training time: 10.5410 seconds
# Epoch 18, Loss: 0.1351, Val Acc: 0.9402, Training time: 10.5610 seconds
# Epoch 19, Loss: 0.1315, Val Acc: 0.9403, Training time: 10.4360 seconds
# Total Time: 211.5580620765686 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 64, 'learning_rate': 0.005, 'num_hidden_layers': 2}
# Epoch 0, Loss: 0.4130, Val Acc: 0.9166, Training time: 6.0870 seconds
# Epoch 1, Loss: 0.2359, Val Acc: 0.9210, Training time: 6.0370 seconds
# Epoch 2, Loss: 0.2168, Val Acc: 0.9266, Training time: 6.1380 seconds
# Epoch 3, Loss: 0.2047, Val Acc: 0.9256, Training time: 7.1370 seconds
# Epoch 4, Loss: 0.1997, Val Acc: 0.9260, Training time: 6.0180 seconds
# Epoch 5, Loss: 0.1934, Val Acc: 0.9279, Training time: 5.9600 seconds
# Epoch 6, Loss: 0.1891, Val Acc: 0.9317, Training time: 5.9860 seconds
# Epoch 7, Loss: 0.1832, Val Acc: 0.9318, Training time: 6.2700 seconds
# Epoch 8, Loss: 0.1782, Val Acc: 0.9296, Training time: 6.0650 seconds
# Epoch 9, Loss: 0.1765, Val Acc: 0.9328, Training time: 6.0380 seconds
# Epoch 10, Loss: 0.1725, Val Acc: 0.9347, Training time: 5.9500 seconds
# Epoch 11, Loss: 0.1689, Val Acc: 0.9316, Training time: 6.0130 seconds
# Epoch 12, Loss: 0.1666, Val Acc: 0.9358, Training time: 6.0420 seconds
# Epoch 13, Loss: 0.1629, Val Acc: 0.9323, Training time: 5.9620 seconds
# Epoch 14, Loss: 0.1608, Val Acc: 0.9346, Training time: 6.0110 seconds
# Epoch 15, Loss: 0.1586, Val Acc: 0.9345, Training time: 6.0280 seconds
# Epoch 16, Loss: 0.1576, Val Acc: 0.9310, Training time: 6.0340 seconds
# Epoch 17, Loss: 0.1535, Val Acc: 0.9356, Training time: 6.0920 seconds
# Epoch 18, Loss: 0.1503, Val Acc: 0.9341, Training time: 6.0550 seconds
# Epoch 19, Loss: 0.1486, Val Acc: 0.9356, Training time: 6.2700 seconds
# Total Time: 122.19303154945374 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 64, 'learning_rate': 0.005, 'num_hidden_layers': 3}
# Epoch 0, Loss: 0.4983, Val Acc: 0.9099, Training time: 8.3600 seconds
# Epoch 1, Loss: 0.2452, Val Acc: 0.9205, Training time: 7.5610 seconds
# Epoch 2, Loss: 0.2200, Val Acc: 0.9199, Training time: 7.6250 seconds
# Epoch 3, Loss: 0.2069, Val Acc: 0.9249, Training time: 7.5280 seconds
# Epoch 4, Loss: 0.1987, Val Acc: 0.9298, Training time: 7.5310 seconds
# Epoch 5, Loss: 0.1908, Val Acc: 0.9288, Training time: 7.6140 seconds
# Epoch 6, Loss: 0.1841, Val Acc: 0.9302, Training time: 7.4670 seconds
# Epoch 7, Loss: 0.1786, Val Acc: 0.9333, Training time: 7.5300 seconds
# Epoch 8, Loss: 0.1726, Val Acc: 0.9338, Training time: 7.6670 seconds
# Epoch 9, Loss: 0.1687, Val Acc: 0.9354, Training time: 7.5090 seconds
# Epoch 10, Loss: 0.1644, Val Acc: 0.9325, Training time: 7.5400 seconds
# Epoch 11, Loss: 0.1622, Val Acc: 0.9372, Training time: 7.5020 seconds
# Epoch 12, Loss: 0.1568, Val Acc: 0.9355, Training time: 7.5290 seconds
# Epoch 13, Loss: 0.1549, Val Acc: 0.9353, Training time: 7.5120 seconds
# Epoch 14, Loss: 0.1502, Val Acc: 0.9367, Training time: 7.5750 seconds
# Epoch 15, Loss: 0.1476, Val Acc: 0.9371, Training time: 7.4890 seconds
# Epoch 16, Loss: 0.1448, Val Acc: 0.9377, Training time: 7.5750 seconds
# Epoch 17, Loss: 0.1431, Val Acc: 0.9378, Training time: 7.6380 seconds
# Epoch 18, Loss: 0.1400, Val Acc: 0.9387, Training time: 7.5610 seconds
# Epoch 19, Loss: 0.1372, Val Acc: 0.9380, Training time: 7.5190 seconds
# Total Time: 151.83203864097595 seconds
# {'activation': 'relu', 'batch_size': 16, 'hidden_units': 64, 'learning_rate': 0.005, 'num_hidden_layers': 4}
# Epoch 0, Loss: 0.5445, Val Acc: 0.9063, Training time: 9.3040 seconds
# Epoch 1, Loss: 0.2475, Val Acc: 0.9180, Training time: 8.9650 seconds
# Epoch 2, Loss: 0.2211, Val Acc: 0.9222, Training time: 8.9020 seconds
# Epoch 3, Loss: 0.2063, Val Acc: 0.9270, Training time: 8.9240 seconds
# Epoch 4, Loss: 0.1952, Val Acc: 0.9277, Training time: 8.8830 seconds
# Epoch 5, Loss: 0.1862, Val Acc: 0.9299, Training time: 8.9370 seconds
# Epoch 6, Loss: 0.1813, Val Acc: 0.9317, Training time: 8.9990 seconds
# Epoch 7, Loss: 0.1737, Val Acc: 0.9318, Training time: 8.9520 seconds
# Epoch 8, Loss: 0.1698, Val Acc: 0.9327, Training time: 8.9280 seconds
# Epoch 9, Loss: 0.1636, Val Acc: 0.9330, Training time: 8.9370 seconds
# Epoch 10, Loss: 0.1607, Val Acc: 0.9355, Training time: 8.9240 seconds
# Epoch 11, Loss: 0.1550, Val Acc: 0.9329, Training time: 9.0290 seconds
# Epoch 12, Loss: 0.1532, Val Acc: 0.9391, Training time: 9.0190 seconds
# Epoch 13, Loss: 0.1499, Val Acc: 0.9375, Training time: 9.2920 seconds
# Epoch 14, Loss: 0.1468, Val Acc: 0.9370, Training time: 8.9660 seconds
# Epoch 15, Loss: 0.1435, Val Acc: 0.9372, Training time: 8.9820 seconds
# ...
# Epoch 17, Loss: 0.1560, Val Acc: 0.9279, Training time: 4.5280 seconds
# Epoch 18, Loss: 0.1516, Val Acc: 0.9361, Training time: 4.6470 seconds
# Epoch 19, Loss: 0.1506, Val Acc: 0.9341, Training time: 4.8160 seconds
# Total Time: 89.96402382850647 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.01, 'num_hidden_layers': 4}
# Epoch 0, Loss: 0.5798, Val Acc: 0.9034, Training time: 5.8220 seconds
# Epoch 1, Loss: 0.2720, Val Acc: 0.9160, Training time: 5.5250 seconds
# Epoch 2, Loss: 0.2321, Val Acc: 0.9232, Training time: 5.4240 seconds
# Epoch 3, Loss: 0.2143, Val Acc: 0.9259, Training time: 5.3220 seconds
# Epoch 4, Loss: 0.2039, Val Acc: 0.9257, Training time: 5.4650 seconds
# Epoch 5, Loss: 0.1964, Val Acc: 0.9279, Training time: 5.5080 seconds
# Epoch 6, Loss: 0.1892, Val Acc: 0.9298, Training time: 5.3540 seconds
# Epoch 7, Loss: 0.1845, Val Acc: 0.9292, Training time: 5.3170 seconds
# Epoch 8, Loss: 0.1884, Val Acc: 0.9303, Training time: 5.2880 seconds
# Epoch 9, Loss: 0.1729, Val Acc: 0.9282, Training time: 5.2420 seconds
# Epoch 10, Loss: 0.1700, Val Acc: 0.9322, Training time: 5.3370 seconds
# Epoch 11, Loss: 0.1662, Val Acc: 0.9321, Training time: 5.3220 seconds
# Epoch 12, Loss: 0.1640, Val Acc: 0.9323, Training time: 5.3160 seconds
# Epoch 13, Loss: 0.1628, Val Acc: 0.9333, Training time: 5.3290 seconds
# Epoch 14, Loss: 0.1545, Val Acc: 0.9355, Training time: 5.2690 seconds
# Epoch 15, Loss: 0.1530, Val Acc: 0.9358, Training time: 5.3550 seconds
# Epoch 16, Loss: 0.1534, Val Acc: 0.9356, Training time: 5.2990 seconds
# Epoch 17, Loss: 0.1495, Val Acc: 0.9348, Training time: 5.2890 seconds
# Epoch 18, Loss: 0.1481, Val Acc: 0.9349, Training time: 5.4310 seconds
# Epoch 19, Loss: 0.1435, Val Acc: 0.9361, Training time: 5.3740 seconds
# Total Time: 107.58803057670593 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.01, 'num_hidden_layers': 5}
# Epoch 0, Loss: 0.6919, Val Acc: 0.8929, Training time: 6.1530 seconds
# Epoch 1, Loss: 0.2867, Val Acc: 0.9142, Training time: 6.2270 seconds
# Epoch 2, Loss: 0.2402, Val Acc: 0.9206, Training time: 6.0860 seconds
# Epoch 3, Loss: 0.2199, Val Acc: 0.9257, Training time: 6.1770 seconds
# Epoch 4, Loss: 0.2069, Val Acc: 0.9260, Training time: 6.0200 seconds
# Epoch 5, Loss: 0.1997, Val Acc: 0.9270, Training time: 6.0710 seconds
# Epoch 6, Loss: 0.1944, Val Acc: 0.9301, Training time: 6.1740 seconds
# Epoch 7, Loss: 0.1799, Val Acc: 0.9319, Training time: 6.1020 seconds
# Epoch 8, Loss: 0.1754, Val Acc: 0.9332, Training time: 6.1210 seconds
# Epoch 9, Loss: 0.1710, Val Acc: 0.9312, Training time: 6.1680 seconds
# Epoch 10, Loss: 0.1680, Val Acc: 0.9347, Training time: 6.0560 seconds
# Epoch 11, Loss: 0.1627, Val Acc: 0.9350, Training time: 6.0910 seconds
# Epoch 12, Loss: 0.1603, Val Acc: 0.9361, Training time: 6.1640 seconds
# Epoch 13, Loss: 0.1551, Val Acc: 0.9340, Training time: 6.1310 seconds
# Epoch 14, Loss: 0.1522, Val Acc: 0.9376, Training time: 6.0960 seconds
# Epoch 15, Loss: 0.1460, Val Acc: 0.9363, Training time: 6.1800 seconds
# Epoch 16, Loss: 0.1451, Val Acc: 0.9225, Training time: 6.1280 seconds
# Epoch 17, Loss: 0.1481, Val Acc: 0.9298, Training time: 6.1170 seconds
# Epoch 18, Loss: 0.1374, Val Acc: 0.9380, Training time: 6.1660 seconds
# Epoch 19, Loss: 0.1382, Val Acc: 0.9378, Training time: 6.2170 seconds
# Total Time: 122.64503455162048 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.005, 'num_hidden_layers': 2}
# Epoch 0, Loss: 0.6085, Val Acc: 0.8976, Training time: 3.6060 seconds
# Epoch 1, Loss: 0.2830, Val Acc: 0.9124, Training time: 3.6390 seconds
# Epoch 2, Loss: 0.2438, Val Acc: 0.9173, Training time: 3.6260 seconds
# Epoch 3, Loss: 0.2282, Val Acc: 0.9209, Training time: 3.5870 seconds
# Epoch 4, Loss: 0.2167, Val Acc: 0.9248, Training time: 3.5980 seconds
# Epoch 5, Loss: 0.2131, Val Acc: 0.9252, Training time: 3.7180 seconds
# Epoch 6, Loss: 0.2059, Val Acc: 0.9286, Training time: 3.5700 seconds
# Epoch 7, Loss: 0.1995, Val Acc: 0.9264, Training time: 3.5450 seconds
# Epoch 8, Loss: 0.1975, Val Acc: 0.9259, Training time: 3.6840 seconds
# Epoch 9, Loss: 0.1935, Val Acc: 0.9282, Training time: 3.6330 seconds
# Epoch 10, Loss: 0.1898, Val Acc: 0.9316, Training time: 3.6190 seconds
# Epoch 11, Loss: 0.1860, Val Acc: 0.9329, Training time: 3.5910 seconds
# Epoch 12, Loss: 0.1847, Val Acc: 0.9308, Training time: 3.5620 seconds
# Epoch 13, Loss: 0.1808, Val Acc: 0.9332, Training time: 3.6180 seconds
# Epoch 14, Loss: 0.1797, Val Acc: 0.9326, Training time: 3.5350 seconds
# Epoch 15, Loss: 0.1775, Val Acc: 0.9313, Training time: 3.6010 seconds
# Epoch 16, Loss: 0.1733, Val Acc: 0.9338, Training time: 3.5900 seconds
# Epoch 17, Loss: 0.1695, Val Acc: 0.9354, Training time: 3.6050 seconds
# Epoch 18, Loss: 0.1693, Val Acc: 0.9332, Training time: 3.5720 seconds
# Epoch 19, Loss: 0.1668, Val Acc: 0.9337, Training time: 3.5530 seconds
# Total Time: 72.05202007293701 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.005, 'num_hidden_layers': 3}
# Epoch 0, Loss: 0.6168, Val Acc: 0.9005, Training time: 4.7840 seconds
# Epoch 1, Loss: 0.2700, Val Acc: 0.9145, Training time: 4.5810 seconds
# Epoch 2, Loss: 0.2345, Val Acc: 0.9216, Training time: 4.5020 seconds
# Epoch 3, Loss: 0.2184, Val Acc: 0.9221, Training time: 4.3970 seconds
# Epoch 4, Loss: 0.2083, Val Acc: 0.9251, Training time: 4.5390 seconds
# Epoch 5, Loss: 0.2054, Val Acc: 0.9279, Training time: 4.8060 seconds
# Epoch 6, Loss: 0.1938, Val Acc: 0.9291, Training time: 4.6690 seconds
# Epoch 7, Loss: 0.1886, Val Acc: 0.9304, Training time: 4.5270 seconds
# Epoch 8, Loss: 0.1861, Val Acc: 0.9294, Training time: 4.4800 seconds
# Epoch 9, Loss: 0.1824, Val Acc: 0.9313, Training time: 4.4010 seconds
# Epoch 10, Loss: 0.1752, Val Acc: 0.9325, Training time: 4.4570 seconds
# Epoch 11, Loss: 0.1716, Val Acc: 0.9329, Training time: 4.6850 seconds
# Epoch 12, Loss: 0.1682, Val Acc: 0.9329, Training time: 4.4710 seconds
# Epoch 13, Loss: 0.1657, Val Acc: 0.9343, Training time: 4.4600 seconds
# Epoch 14, Loss: 0.1628, Val Acc: 0.9352, Training time: 4.5470 seconds
# Epoch 15, Loss: 0.1595, Val Acc: 0.9349, Training time: 4.4700 seconds
# Epoch 16, Loss: 0.1605, Val Acc: 0.9361, Training time: 4.4480 seconds
# Epoch 17, Loss: 0.1596, Val Acc: 0.9375, Training time: 4.4280 seconds
# Epoch 18, Loss: 0.1557, Val Acc: 0.9335, Training time: 4.4860 seconds
# Epoch 19, Loss: 0.1511, Val Acc: 0.9369, Training time: 4.4700 seconds
# Total Time: 90.6080265045166 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.005, 'num_hidden_layers': 4}
# Epoch 0, Loss: 0.5852, Val Acc: 0.9055, Training time: 5.2460 seconds
# Epoch 1, Loss: 0.2665, Val Acc: 0.9186, Training time: 5.3490 seconds
# Epoch 2, Loss: 0.2349, Val Acc: 0.9209, Training time: 5.2130 seconds
# Epoch 3, Loss: 0.2138, Val Acc: 0.9238, Training time: 5.3060 seconds
# Epoch 4, Loss: 0.2009, Val Acc: 0.9291, Training time: 5.3310 seconds
# Epoch 5, Loss: 0.1934, Val Acc: 0.9277, Training time: 5.3060 seconds
# Epoch 6, Loss: 0.1893, Val Acc: 0.9264, Training time: 5.2270 seconds
# Epoch 7, Loss: 0.1861, Val Acc: 0.9299, Training time: 5.2460 seconds
# Epoch 8, Loss: 0.1760, Val Acc: 0.9317, Training time: 5.1550 seconds
# Epoch 9, Loss: 0.1708, Val Acc: 0.9319, Training time: 5.2690 seconds
# Epoch 10, Loss: 0.1710, Val Acc: 0.9344, Training time: 5.2960 seconds
# Epoch 11, Loss: 0.1659, Val Acc: 0.9358, Training time: 5.3290 seconds
# Epoch 12, Loss: 0.1621, Val Acc: 0.9344, Training time: 5.3150 seconds
# Epoch 13, Loss: 0.1592, Val Acc: 0.9340, Training time: 5.3040 seconds
# Epoch 14, Loss: 0.1536, Val Acc: 0.9376, Training time: 5.9080 seconds
# Epoch 15, Loss: 0.1519, Val Acc: 0.9352, Training time: 5.4460 seconds
# Epoch 16, Loss: 0.1493, Val Acc: 0.9354, Training time: 5.3430 seconds
# Epoch 17, Loss: 0.1456, Val Acc: 0.9365, Training time: 5.2680 seconds
# Epoch 18, Loss: 0.1454, Val Acc: 0.9392, Training time: 5.4040 seconds
# Epoch 19, Loss: 0.1400, Val Acc: 0.9357, Training time: 5.2360 seconds
# Total Time: 106.49702739715576 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.005, 'num_hidden_layers': 5}
# Epoch 0, Loss: 0.6641, Val Acc: 0.8978, Training time: 6.2230 seconds
# Epoch 1, Loss: 0.2765, Val Acc: 0.9162, Training time: 6.2280 seconds
# Epoch 2, Loss: 0.2345, Val Acc: 0.9191, Training time: 6.1060 seconds
# Epoch 3, Loss: 0.2168, Val Acc: 0.9208, Training time: 6.0910 seconds
# Epoch 4, Loss: 0.2050, Val Acc: 0.9275, Training time: 6.1190 seconds
# Epoch 5, Loss: 0.1951, Val Acc: 0.9270, Training time: 6.1030 seconds
# Epoch 6, Loss: 0.1907, Val Acc: 0.9285, Training time: 6.1080 seconds
# Epoch 7, Loss: 0.1849, Val Acc: 0.9284, Training time: 6.0670 seconds
# Epoch 8, Loss: 0.1805, Val Acc: 0.9295, Training time: 6.0500 seconds
# Epoch 9, Loss: 0.1728, Val Acc: 0.9311, Training time: 6.4030 seconds
# Epoch 10, Loss: 0.1688, Val Acc: 0.9316, Training time: 6.1110 seconds
# Epoch 11, Loss: 0.1632, Val Acc: 0.9328, Training time: 6.1370 seconds
# Epoch 12, Loss: 0.1630, Val Acc: 0.9322, Training time: 6.0680 seconds
# Epoch 13, Loss: 0.1603, Val Acc: 0.9327, Training time: 6.2010 seconds
# Epoch 14, Loss: 0.1552, Val Acc: 0.9332, Training time: 6.0690 seconds
# Epoch 15, Loss: 0.1486, Val Acc: 0.9345, Training time: 6.1880 seconds
# Epoch 16, Loss: 0.1467, Val Acc: 0.9349, Training time: 6.2930 seconds
# Epoch 17, Loss: 0.1422, Val Acc: 0.9346, Training time: 6.1030 seconds
# Epoch 18, Loss: 0.1418, Val Acc: 0.9346, Training time: 6.0600 seconds
# Epoch 19, Loss: 0.1390, Val Acc: 0.9350, Training time: 6.1280 seconds
# Total Time: 122.85603594779968 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.001, 'num_hidden_layers': 2}
# Epoch 0, Loss: 0.6660, Val Acc: 0.8980, Training time: 3.7290 seconds
# Epoch 1, Loss: 0.2825, Val Acc: 0.9171, Training time: 3.6330 seconds
# Epoch 2, Loss: 0.2443, Val Acc: 0.9209, Training time: 3.6060 seconds
# Epoch 3, Loss: 0.2259, Val Acc: 0.9229, Training time: 3.5760 seconds
# Epoch 4, Loss: 0.2181, Val Acc: 0.9256, Training time: 3.5890 seconds
# Epoch 5, Loss: 0.2099, Val Acc: 0.9264, Training time: 3.5840 seconds
# Epoch 6, Loss: 0.2052, Val Acc: 0.9256, Training time: 3.5870 seconds
# Epoch 7, Loss: 0.1987, Val Acc: 0.9296, Training time: 3.5610 seconds
# Epoch 8, Loss: 0.1929, Val Acc: 0.9300, Training time: 3.5970 seconds
# Epoch 9, Loss: 0.1933, Val Acc: 0.9323, Training time: 3.5730 seconds
# Epoch 10, Loss: 0.1906, Val Acc: 0.9291, Training time: 3.6400 seconds
# Epoch 11, Loss: 0.1850, Val Acc: 0.9325, Training time: 3.5960 seconds
# Epoch 12, Loss: 0.1804, Val Acc: 0.9316, Training time: 3.5340 seconds
# Epoch 13, Loss: 0.1787, Val Acc: 0.9336, Training time: 3.5750 seconds
# Epoch 14, Loss: 0.1763, Val Acc: 0.9351, Training time: 3.5970 seconds
# Epoch 15, Loss: 0.1743, Val Acc: 0.9350, Training time: 3.5710 seconds
# Epoch 16, Loss: 0.1748, Val Acc: 0.9351, Training time: 3.5400 seconds
# Epoch 17, Loss: 0.1690, Val Acc: 0.9340, Training time: 3.5430 seconds
# Epoch 18, Loss: 0.1702, Val Acc: 0.9332, Training time: 3.6300 seconds
# Epoch 19, Loss: 0.1668, Val Acc: 0.9349, Training time: 3.5810 seconds
# Total Time: 71.84202075004578 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.001, 'num_hidden_layers': 3}
# Epoch 0, Loss: 0.5905, Val Acc: 0.8922, Training time: 4.4410 seconds
# Epoch 1, Loss: 0.2749, Val Acc: 0.9131, Training time: 4.4740 seconds
# Epoch 2, Loss: 0.2389, Val Acc: 0.9181, Training time: 4.3710 seconds
# Epoch 3, Loss: 0.2207, Val Acc: 0.9207, Training time: 4.4480 seconds
# Epoch 4, Loss: 0.2105, Val Acc: 0.9254, Training time: 4.3990 seconds
# Epoch 5, Loss: 0.2055, Val Acc: 0.9271, Training time: 4.5790 seconds
# Epoch 6, Loss: 0.1933, Val Acc: 0.9285, Training time: 4.4530 seconds
# Epoch 7, Loss: 0.1893, Val Acc: 0.9300, Training time: 4.5040 seconds
# Epoch 8, Loss: 0.1836, Val Acc: 0.9296, Training time: 4.8900 seconds
# Epoch 9, Loss: 0.1830, Val Acc: 0.9315, Training time: 4.6890 seconds
# Epoch 10, Loss: 0.1789, Val Acc: 0.9301, Training time: 4.6900 seconds
# Epoch 11, Loss: 0.1730, Val Acc: 0.9343, Training time: 4.4830 seconds
# Epoch 12, Loss: 0.1689, Val Acc: 0.9335, Training time: 4.5930 seconds
# Epoch 13, Loss: 0.1653, Val Acc: 0.9352, Training time: 4.5110 seconds
# Epoch 14, Loss: 0.1645, Val Acc: 0.9342, Training time: 4.4930 seconds
# Epoch 15, Loss: 0.1610, Val Acc: 0.9361, Training time: 4.4060 seconds
# Epoch 16, Loss: 0.1601, Val Acc: 0.9364, Training time: 4.4340 seconds
# Epoch 17, Loss: 0.1552, Val Acc: 0.9337, Training time: 4.4950 seconds
# Epoch 18, Loss: 0.1526, Val Acc: 0.9386, Training time: 4.5570 seconds
# Epoch 19, Loss: 0.1502, Val Acc: 0.9325, Training time: 4.4950 seconds
# Total Time: 90.40502500534058 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.001, 'num_hidden_layers': 4}
# Epoch 0, Loss: 0.6278, Val Acc: 0.8986, Training time: 5.4740 seconds
# Epoch 1, Loss: 0.2797, Val Acc: 0.9103, Training time: 5.3700 seconds
# Epoch 2, Loss: 0.2392, Val Acc: 0.9194, Training time: 5.2980 seconds
# Epoch 3, Loss: 0.2217, Val Acc: 0.9232, Training time: 5.3370 seconds
# Epoch 4, Loss: 0.2066, Val Acc: 0.9258, Training time: 5.6830 seconds
# Epoch 5, Loss: 0.1969, Val Acc: 0.9277, Training time: 5.5200 seconds
# Epoch 6, Loss: 0.1931, Val Acc: 0.9258, Training time: 5.4920 seconds
# Epoch 7, Loss: 0.1901, Val Acc: 0.9304, Training time: 5.2700 seconds
# Epoch 8, Loss: 0.1859, Val Acc: 0.9297, Training time: 5.2890 seconds
# Epoch 9, Loss: 0.1845, Val Acc: 0.9306, Training time: 5.3000 seconds
# Epoch 10, Loss: 0.1722, Val Acc: 0.9310, Training time: 5.3920 seconds
# Epoch 11, Loss: 0.1653, Val Acc: 0.9332, Training time: 5.7350 seconds
# Epoch 12, Loss: 0.1643, Val Acc: 0.9132, Training time: 5.2850 seconds
# Epoch 13, Loss: 0.1619, Val Acc: 0.9353, Training time: 5.3210 seconds
# Epoch 14, Loss: 0.1570, Val Acc: 0.9355, Training time: 5.3610 seconds
# Epoch 15, Loss: 0.1539, Val Acc: 0.9370, Training time: 5.3230 seconds
# Epoch 16, Loss: 0.1502, Val Acc: 0.9393, Training time: 5.2600 seconds
# Epoch 17, Loss: 0.1547, Val Acc: 0.9357, Training time: 5.3630 seconds
# Epoch 18, Loss: 0.1463, Val Acc: 0.9392, Training time: 5.3020 seconds
# Epoch 19, Loss: 0.1406, Val Acc: 0.9350, Training time: 5.4910 seconds
# Total Time: 107.86603116989136 seconds
# {'activation': 'tanh', 'batch_size': 64, 'hidden_units': 64, 'learning_rate': 0.001, 'num_hidden_layers': 5}
# Epoch 0, Loss: 0.7165, Val Acc: 0.8926, Training time: 6.1400 seconds
# Epoch 1, Loss: 0.2912, Val Acc: 0.9109, Training time: 6.1440 seconds
# Epoch 2, Loss: 0.2475, Val Acc: 0.9182, Training time: 6.0970 seconds
# Epoch 3, Loss: 0.2269, Val Acc: 0.9213, Training time: 6.1170 seconds
# Epoch 4, Loss: 0.2127, Val Acc: 0.9245, Training time: 6.0340 seconds
# Epoch 5, Loss: 0.2011, Val Acc: 0.9274, Training time: 6.1780 seconds
# Epoch 6, Loss: 0.1918, Val Acc: 0.9275, Training time: 6.1080 seconds
# Epoch 7, Loss: 0.1850, Val Acc: 0.9291, Training time: 6.1150 seconds
# Epoch 8, Loss: 0.1782, Val Acc: 0.9329, Training time: 6.0750 seconds
# Epoch 9, Loss: 0.1747, Val Acc: 0.9318, Training time: 6.2010 seconds
# Epoch 10, Loss: 0.1690, Val Acc: 0.9307, Training time: 6.3100 seconds
# Epoch 11, Loss: 0.1630, Val Acc: 0.9301, Training time: 6.0550 seconds
# Epoch 12, Loss: 0.1631, Val Acc: 0.9322, Training time: 6.1030 seconds
# Epoch 13, Loss: 0.1594, Val Acc: 0.9342, Training time: 6.1390 seconds
# Epoch 14, Loss: 0.1536, Val Acc: 0.9364, Training time: 6.1150 seconds
# Epoch 15, Loss: 0.1518, Val Acc: 0.9345, Training time: 6.1150 seconds
# Epoch 16, Loss: 0.1478, Val Acc: 0.9253, Training time: 6.0360 seconds
# Epoch 17, Loss: 0.1482, Val Acc: 0.9329, Training time: 6.0740 seconds
# Epoch 18, Loss: 0.1497, Val Acc: 0.9357, Training time: 6.0830 seconds
# Epoch 19, Loss: 0.1427, Val Acc: 0.9354, Training time: 6.1230 seconds
# Total Time: 122.36203289031982 seconds
# Best Validation Accuracy:  0.9420683215592653
# Best Parameters:  {'activation': 'tanh', 'batch_size': 16, 'hidden_units': 64, 'learning_rate': 0.001, 'num_hidden_layers': 4}

# %%
import torch
import numpy as np
from dgl.dataloading import GraphDataLoader
from sklearn.metrics import precision_recall_fscore_support


def evaluate_model(model, dgl_graphs):
    """
    Evaluate the provided model on the given graphs.
    
    Parameters:
    model (nn.Module): The model to be evaluated.
    dgl_graphs (list): A list of DGL Graph objects to be used for evaluation.
    
    Returns:
    dict: A dictionary containing the Accuracy, Precision, Recall, and F1 Score of the model on the test data.
    """
    # Initialization of lists to store the true labels and the predicted labels
    all_labels = []
    all_preds = []
    total_correct = 0
    total_samples = 0
    
    # Set the model to evaluation mode
    model.eval()
    
    # Define the test data loader
    test_dataloader = GraphDataLoader(dgl_graphs, batch_size=32, shuffle=False)
    
    # Iterate over the test data
    for batched_graph in test_dataloader:
        # Extract features, labels, and the test mask from the batched graph
        features = batched_graph.ndata['feat']
        labels = batched_graph.ndata['label']
        test_mask = batched_graph.ndata['test_mask']
        
        # Perform forward pass through the model to get the logits
        logits = model(batched_graph, features)
        
        # Get predictions
        _, predicted = torch.max(logits, 1)
        
        # Update the correct predictions count and total samples count
        total_correct += (predicted == labels).float().sum().item()
        total_samples += len(labels)
        
        # Store the true and predicted labels
        all_labels.append(labels[test_mask].cpu().numpy())
        all_preds.append(predicted[test_mask].cpu().numpy())
    
    # Convert the list of true and predicted labels to NumPy arrays
    all_labels = np.concatenate(all_labels)
    all_preds = np.concatenate(all_preds)
    
    # Compute Precision, Recall, and F1 Score
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')
    test_acc = total_correct / total_samples
    
    # Return the computed metrics as a dictionary
    return {
        'Test Accuracy': test_acc,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    }

# %%
# Create a model instance with the same structure as the saved model
model = SAGEModel(in_feats=7, num_classes=9, params=best_params)  

# Load the model weights
model.load_state_dict(torch.load('best_model.pth'))

# Evaluate the model and print the results
results = evaluate_model(model, dgl_graphs)
print(f"Test Accuracy: {results['Test Accuracy']:.4f}")
print(f"Precision: {results['Precision']:.4f}")
print(f"Recall: {results['Recall']:.4f}")
print(f"F1 Score: {results['F1 Score']:.4f}")
# Out:
# Test Accuracy: 0.9474
# Precision: 0.8655
# Recall: 0.7990
# F1 Score: 0.8148
